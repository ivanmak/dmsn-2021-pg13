# %%
from temporal_networkx import TemporalDiGraph
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import math
import seaborn as sb
from datetime import datetime, timedelta
from copy import deepcopy

# %%
temporal_graph = TemporalDiGraph(pd.read_csv('./soc-sign-bitcoinotc.csv', header=None))

# %% [markdown]
# # Simulation of Banning Users

# %% [markdown]
# ## Preparation of Methods

# %% [markdown]
# First, snapshots of the directed graph for the whole dataset is saved for comparison during simulation.

# %%
first_month = str(temporal_graph.get_all_months()[0])
end_month = str(temporal_graph.get_all_months()[-1])

# %%
baseline_graph = deepcopy(temporal_graph.get_DiGraph(first_month, end_month, True, True))

# %% [markdown]
# ### Banning a Single User

# %% [markdown]
# The parameters of the method are:
# * node_id (int) - Node ID of the user in the dataset.
# * ban_month (str) - Month when the user is banned (after the month has ended), in YYYY-MM format.
# * rating_threshold (float) - Any rating below this threshold would be considered as a bad rating. Defaults to 0.0.
# * fairness_threshold (float) - Any edge fairness below this threshold would be considered as a biased rating. Defaults to 0.0.
# * verbose (bool) - Whether the simulation is run verbosely.
#
# The method returns a dictionary with the following information:
# * Final goodness score of the user
# * Final average rating of the user
# * Rating, fairness and count of the in-edges and out-edges of the user in the future
#
# Unit test of the method:

# %%
def ban_user(user_to_be_banned: int, ban_month: str,
             rating_threshold: float=0.0,
             fairness_threshold: float=0.0,
             verbose: bool=False):
    future_of_the_user = {
        'node_id': user_to_be_banned,
        'final_goodness': monthly_baseline_graphs[end_month].nodes[user_to_be_banned]['goodness'],
        'final_average_rating': monthly_baseline_graphs[end_month].nodes[user_to_be_banned]['average_rating'],
        'future_in_edges': [],
        'future_out_edges': [],
        'bad_in_edges': 0,
        'good_in_edges': 0,
        'fair_bad_in_edges': 0,
        'fair_good_in_edges': 0,
        'bias_bad_in_edges': 0,
        'bias_good_in_edges': 0,
        'bad_out_edges': 0,
        'good_out_edges': 0,
        'fair_bad_out_edges': 0,
        'fair_good_out_edges': 0,
        'bias_bad_out_edges': 0,
        'bias_good_out_edges': 0
    }

    # Find out all edges of this user AFTER ban_month
    # (simulating users being banned at the end of each month)
    ban_month_dt = datetime.strptime(ban_month, '%Y-%m')
    ban_month_dt = ban_month_dt.replace(day=1, hour=0, minute=0, second=0, microsecond=0)
    next_month_dt = ban_month_dt + timedelta(days=31)
    next_month_dt = ban_month_dt.replace(day=1, hour=0, minute=0, second=0, microsecond=0)

    # Find out all in-edges of the user in this month
    for edge in baseline_graph.in_edges(user_to_be_banned, data=True):
        if edge[2]['time'] >= next_month_dt:
            if edge[2]['weight'] < rating_threshold:
                future_of_the_user['bad_in_edges'] = future_of_the_user['bad_in_edges'] + 1

                if edge[2]['fairness'] < fairness_threshold:
                    future_of_the_user['bias_bad_in_edges'] = future_of_the_user['bias_bad_in_edges'] + 1
                else:
                    future_of_the_user['fair_bad_in_edges'] = future_of_the_user['fair_bad_in_edges'] + 1
            else:
                future_of_the_user['good_in_edges'] = future_of_the_user['good_in_edges'] + 1

                if edge[2]['fairness'] < fairness_threshold:
                    future_of_the_user['bias_good_in_edges'] = future_of_the_user['bias_good_in_edges'] + 1
                else:
                    future_of_the_user['fair_good_in_edges'] = future_of_the_user['fair_good_in_edges'] + 1

            edge_item = {
                'weight': edge[2]['weight'],
                'fairness': edge[2]['fairness']
            }
            future_of_the_user['future_in_edges'].append(edge_item)

    for edge in baseline_graph.out_edges(user_to_be_banned, data=True):
        if edge[2]['time'] >= next_month_dt:
            if edge[2]['weight'] < rating_threshold:
                future_of_the_user['bad_out_edges'] = future_of_the_user['bad_out_edges'] + 1

                if edge[2]['fairness'] < fairness_threshold:
                    future_of_the_user['bias_bad_out_edges'] = future_of_the_user['bias_bad_out_edges'] + 1
                else:
                    future_of_the_user['fair_bad_out_edges'] = future_of_the_user['fair_bad_out_edges'] + 1
            else:
                future_of_the_user['good_out_edges'] = future_of_the_user['good_out_edges'] + 1

                if edge[2]['fairness'] < fairness_threshold:
                    future_of_the_user['bias_good_out_edges'] = future_of_the_user['bias_good_out_edges'] + 1
                else:
                    future_of_the_user['fair_good_out_edges'] = future_of_the_user['fair_good_out_edges'] + 1

            edge_item = {
                'weight': edge[2]['weight'],
                'fairness': edge[2]['fairness']
            }
            future_of_the_user['future_out_edges'].append(edge_item)
        
    if verbose:
        print(f"At end of the baseline dataset, the {user_to_be_banned} had a final average rating of {future_of_the_user['final_average_rating']}, and final goodness score of {future_of_the_user['final_goodness']}.")

        print(f"Banning the user would have prevent {future_of_the_user['bad_in_edges']} bad in-edges ({future_of_the_user['fair_bad_in_edges']} fair, {future_of_the_user['bias_bad_in_edges']} biased) and {future_of_the_user['good_in_edges']} good in-edges ({future_of_the_user['fair_good_in_edges']} fair, {future_of_the_user['bias_good_in_edges']} biased),")

        print(f"and {future_of_the_user['bad_out_edges']} bad out-edges ({future_of_the_user['fair_bad_out_edges']} fair, {future_of_the_user['bias_bad_out_edges']} biased) and {future_of_the_user['good_out_edges']} good out-edges ({future_of_the_user['fair_good_out_edges']} fair, {future_of_the_user['bias_good_out_edges']} biased).")
    
    return future_of_the_user

# %%
result = ban_user(103, '2011-05', 0.0, 0.0, True)
# Out:
# At end of the baseline dataset, the 103 had a final average rating of 1.0, and final goodness score of 0.6346669696017236.
# Banning the user would have prevent 0 bad in-edges (0 fair, 0 biased) and 0 good in-edges (0 fair, 0 biased),
# and 0 bad out-edges (0 fair, 0 biased) and 0 good out-edges (0 fair, 0 biased).

# %%
result = ban_user(179, '2011-03', 0.0, 0.0, True)
# Out:
# At end of the baseline dataset, the 179 had a final average rating of -0.42857142857142855, and final goodness score of -0.11512300644992719.
# Banning the user would have prevent 5 bad in-edges (5 fair, 0 biased) and 1 good in-edges (1 fair, 0 biased),
# and 0 bad out-edges (0 fair, 0 biased) and 1 good out-edges (1 fair, 0 biased).

# %% [markdown]
# ### Banning Bad Users at the End of Each Month

# %% [markdown]
# After defining the method to simulate the effect of banning one user, the following method finds out bad users at the end of each month of the dataset, and simulates the effects of banning the bad users.

# %% [markdown]
# The parameters of this method are:
# * criterion (str): Can be 'goodness' meaning to REV2 goodness score to find out bad users, or 'average' or 'average_rating' meaning to use average rating to find out bad users.
# * threshold (float): Users having goodness score OR average rating below this threshold would be considered as bad users, and simulation would run on these users.
# * verbose (bool): Whether this method should be run verbosely.
# * verbose_ban_user (bool): Whether the simulation of banning individual users should be run verbosely. Default to False.
#
# The method would return the following pd.DataFrame objects:
# * users_banned_average_df - The final goodness score and average rating of the users being banned.
# * in_edges_removed_df - Rating and fairness of the in-edges that would have been prevented as a result of users being banned.
# * out_edges_removed_df- Rating and fairness of the out-edges that would have been prevented as a result of users being banned.

# %%
def simulation(criterion: str, threshold: float, verbose: bool, verbose_ban_user: bool=False):

    if criterion not in ['goodness', 'average', 'average_rating']:
        raise RuntimeError("criterion should be either 'goodness' or 'average', 'average_rating'")
    
    run_REV2 = False
    calc_avg = False

    if criterion == 'goodness':
        run_REV2 = True

    if criterion == 'average' or criterion == 'average_rating':
        calc_avg = True
        criterion = 'average_rating'

    sep = '---------------------------------------------------------------------------'

    # a list storing banned users in form of tuples:
    #   (month, user_id, final_goodness, final_average_rating)
    users_banned = []

    # a list storing removed in-edges in form of tuples
    #   (month, rating, fairness)
    in_edges_removed = []

    # a list storing removed out-edges in form of tuples
    #   (month, rating, fairness)
    out_edges_removed = []


    if verbose:
        print(f'Running simulation of banning users based on {criterion} with threshold of {threshold}')
        print(sep)

    # Loop thru all rolling months
    for month in temporal_graph.get_all_months():
        month = str(month)

        if verbose:
            print(f'Simulating for the month {month}')

        simulation_graph = deepcopy(temporal_graph)
        
        # Remove users that were already banned from simulation_graph
        months_banned = set([ rec[0] for rec in users_banned ])
        for k in months_banned:
            if k < month:
                # Only drop the in-edges from the current month
                banned_users = [-1, -2] + [ rec[1] for rec in users_banned if rec[0] == k ]
                simulation_graph.df = simulation_graph.df.drop(
                    simulation_graph.df[simulation_graph.df.index > k]
                    .query(f"target in ({','.join([str(x) for x in banned_users])})").index
                )
                simulation_graph.df = simulation_graph.df.drop(
                    simulation_graph.df[simulation_graph.df.index > k]
                    .query(f"source in ({','.join([str(x) for x in banned_users])})").index
                )
        G = simulation_graph.get_DiGraph(first_month, month, run_REV2=run_REV2, calc_average=calc_avg)
        # Find out bad users
        bad_users = [node[0] for node in G.nodes(data=True) if node[1][criterion] is not None and node[1][criterion] < threshold]

        
        for k in months_banned:
            if k < month:
                users_banned_this_month = [rec[1] for rec in users_banned if rec[0] == k]
                if len(users_banned_this_month) > 0:
                    bad_users = [b for b in bad_users if b not in users_banned_this_month]

        if verbose:
            print('Effects of banning users in this month:')
            print(f"{len(bad_users)} bad user(s) were banned")

        future_changed = False
        for bad_user in bad_users:
            future_changed = True
            results = ban_user(bad_user, month, 0, 0, verbose_ban_user)

            # added record to user_banned (month, user_id, final_goodness, final_average_rating)
            item = (month, results['node_id'], results['final_goodness'], results['final_average_rating'])
            users_banned.append(item)

            # add records to in_edges_removed (month, rating, fairness)
            for in_edge in results['future_in_edges']:
                item = (month, in_edge['weight'], in_edge['fairness'])
                in_edges_removed.append(item)

            # add records to out_edges_removed (month, rating, fairness)
            for out_edge in results['future_out_edges']:
                item = (month, out_edge['weight'], out_edge['fairness'])
                out_edges_removed.append(item)

        if verbose:
            if future_changed:
                this_month_bad_users = 0
                this_month_good_users = 0
                if criterion == 'goodness':
                    this_month_bad_users = [ 1 for rec in users_banned if rec[0] == month and rec[2] < threshold ]
                    this_month_good_users = [ 1 for rec in users_banned if rec[0] == month and rec[2] >= threshold ]
                else:
                    this_month_bad_users = [ 1 for rec in users_banned if rec[0] == month and rec[3] < threshold ]
                    this_month_good_users = [ 1 for rec in users_banned if rec[0] == month and rec[3] >= threshold ]

                this_month_bad_users = len(this_month_bad_users)
                this_month_good_users = len(this_month_good_users)

                print('Final scores/ratings of banned users in this month:')
                print(f'{this_month_bad_users} users would have had final {criterion} < {threshold}')
                print(f'{this_month_good_users} users would have had final {criterion} >= {threshold}')

                num_in_edges = len([1 for rec in in_edges_removed if rec[0] == month])
                num_bad_in_edges = len([1 for rec in in_edges_removed if rec[0] == month and rec[1] < 0])
                num_good_in_edges = len([1 for rec in in_edges_removed if rec[0] == month and rec[1] > 0])

                print('\n')
                print(f'{num_in_edges} in-edge(s) would have been prevented:')
                print(f'{num_bad_in_edges} bad rating(s), {num_good_in_edges} good rating(s)')

                num_out_edges = len([1 for rec in out_edges_removed if rec[0] == month])
                num_bad_out_edges = len([1 for rec in out_edges_removed if rec[0] == month and rec[1] < 0])
                num_good_out_edges = len([1 for rec in out_edges_removed if rec[0] == month and rec[1] > 0])

                print('\n')
                print(f'{num_out_edges} out-edge(s) would have been prevented:')
                print(f'{num_bad_out_edges} bad rating(s), {num_good_out_edges} good rating(s)')
            else:
                print('Simulation of this month would not have affected the future')
            print(sep)
    
    if verbose:
        print('Final simulation results:')
        num_bad_users = 0
        num_good_users = 0
        if criterion == 'goodness':
            num_bad_users = [ 1 for rec in users_banned if rec[2] < threshold ]
            num_good_users = [ 1 for rec in users_banned if rec[2] >= threshold ]
        else:
            num_bad_users = [ 1 for rec in users_banned if rec[3] < threshold ]
            num_good_users = [ 1 for rec in users_banned if rec[3] >= threshold ]

        num_bad_users = len(num_bad_users)
        num_good_users = len(num_good_users)

        print('Final scores/ratings of banned users:')
        print(f'{num_bad_users} users would have had final {criterion} < {threshold}')
        print(f'{num_good_users} users would have had final {criterion} >= {threshold}')

        num_in_edges = len(in_edges_removed)
        num_bad_in_edges = len([1 for rec in in_edges_removed if rec[1] < 0])
        num_good_in_edges = len([1 for rec in in_edges_removed if rec[1] > 0])

        print('\n')
        print(f'{num_in_edges} in-edge(s) would have been prevented:')
        print(f'{num_bad_in_edges} bad rating(s), {num_good_in_edges} good rating(s)')

        num_out_edges = len(out_edges_removed)
        num_bad_out_edges = len([1 for rec in out_edges_removed if rec[1] < 0])
        num_fair_bad_out_edges = len([1 for rec in out_edges_removed if rec[1] < 0 and rec[2] >= 0])
        num_bias_bad_out_edges = len([1 for rec in out_edges_removed if rec[1] < 0 and rec[2] < 0])
        num_good_out_edges = len([1 for rec in out_edges_removed if rec[1] > 0])
        num_fair_good_out_edges = len([1 for rec in out_edges_removed if rec[1] > 0 and rec[2] >= 0])
        num_bias_good_out_edges = len([1 for rec in out_edges_removed if rec[1] > 0 and rec[2] < 0])

        print('\n')
        print(f'{num_out_edges} out-edge(s) would have been prevented:')
        print(f'{num_bad_out_edges} bad rating(s), {num_good_out_edges} good rating(s)')

    users_banned_average_df = pd.DataFrame.from_records(
        users_banned_average,
        columns=['month', 'node_id', 'final_goodness', 'final_average_rating'])

    in_edges_removed_df = pd.DataFrame.from_records(
        in_edges_removed,
        columns=['month', 'rating', 'fairness']
    )

    out_edges_removed_df = pd.DataFrame.from_records(
        out_edges_removed,
        columns=['month', 'rating', 'fairness']
    )

    return users_banned_average_df, in_edges_removed_df, out_edges_removed_df

# %% [markdown]
# ## Simulations

# %% [markdown]
# ### Simulation Using Average Ratings

# %%
users_banned_average, in_edges_removed_average, out_edges_removed_average = simulation('average', 0, True)
# Out:
# Running simulation of banning users based on average_rating with threshold of 0
# ---------------------------------------------------------------------------
# Simulating for the month 2010-11
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2010-12
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2011-01
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2011-02
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2011-03
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 6 in-edge(s) would have been prevented:
# 5 bad rating(s), 1 good rating(s)
#
#
# 1 out-edge(s) would have been prevented:
# 0 bad rating(s), 1 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-04
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 2 in-edge(s) would have been prevented:
# 1 bad rating(s), 1 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-05
# Effects of banning users in this month:
# 9 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 9 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 48 in-edge(s) would have been prevented:
# 29 bad rating(s), 19 good rating(s)
#
#
# 24 out-edge(s) would have been prevented:
# 1 bad rating(s), 23 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-06
# Effects of banning users in this month:
# 20 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 19 users would have had final average_rating < 0
# 1 users would have had final average_rating >= 0
#
#
# 88 in-edge(s) would have been prevented:
# 53 bad rating(s), 35 good rating(s)
#
#
# 69 out-edge(s) would have been prevented:
# 10 bad rating(s), 59 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-07
# Effects of banning users in this month:
# 9 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 9 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 16 in-edge(s) would have been prevented:
# 15 bad rating(s), 1 good rating(s)
#
#
# 1 out-edge(s) would have been prevented:
# 0 bad rating(s), 1 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-08
# Effects of banning users in this month:
# 3 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 3 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 8 in-edge(s) would have been prevented:
# 8 bad rating(s), 0 good rating(s)
#
#
# 2 out-edge(s) would have been prevented:
# 0 bad rating(s), 2 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-09
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2011-10
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 1 in-edge(s) would have been prevented:
# 1 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-11
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 1 in-edge(s) would have been prevented:
# 1 bad rating(s), 0 good rating(s)
#
#
# 1 out-edge(s) would have been prevented:
# 0 bad rating(s), 1 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-12
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 0 users would have had final average_rating < 0
# 1 users would have had final average_rating >= 0
#
#
# 0 in-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-01
# Effects of banning users in this month:
# 4 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 4 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 10 in-edge(s) would have been prevented:
# 10 bad rating(s), 0 good rating(s)
#
#
# 3 out-edge(s) would have been prevented:
# 1 bad rating(s), 2 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-02
# Effects of banning users in this month:
# 2 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 2 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 5 in-edge(s) would have been prevented:
# 4 bad rating(s), 1 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-03
# Effects of banning users in this month:
# 5 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 5 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 20 in-edge(s) would have been prevented:
# 15 bad rating(s), 5 good rating(s)
#
#
# 8 out-edge(s) would have been prevented:
# 0 bad rating(s), 8 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-04
# Effects of banning users in this month:
# 6 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 6 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 20 in-edge(s) would have been prevented:
# 18 bad rating(s), 2 good rating(s)
#
#
# 7 out-edge(s) would have been prevented:
# 0 bad rating(s), 7 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-05
# Effects of banning users in this month:
# 2 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 2 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 11 in-edge(s) would have been prevented:
# 10 bad rating(s), 1 good rating(s)
#
#
# 2 out-edge(s) would have been prevented:
# 0 bad rating(s), 2 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-06
# Effects of banning users in this month:
# 9 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 9 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 23 in-edge(s) would have been prevented:
# 19 bad rating(s), 4 good rating(s)
#
#
# 12 out-edge(s) would have been prevented:
# 1 bad rating(s), 11 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-07
# Effects of banning users in this month:
# 11 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 10 users would have had final average_rating < 0
# 1 users would have had final average_rating >= 0
#
#
# 61 in-edge(s) would have been prevented:
# 24 bad rating(s), 37 good rating(s)
#
#
# 55 out-edge(s) would have been prevented:
# 12 bad rating(s), 43 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-08
# Effects of banning users in this month:
# 14 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 12 users would have had final average_rating < 0
# 2 users would have had final average_rating >= 0
#
#
# 98 in-edge(s) would have been prevented:
# 74 bad rating(s), 24 good rating(s)
#
#
# 27 out-edge(s) would have been prevented:
# 2 bad rating(s), 25 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-09
# Effects of banning users in this month:
# 71 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 69 users would have had final average_rating < 0
# 2 users would have had final average_rating >= 0
#
#
# 370 in-edge(s) would have been prevented:
# 250 bad rating(s), 120 good rating(s)
#
#
# 161 out-edge(s) would have been prevented:
# 22 bad rating(s), 139 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-10
# Effects of banning users in this month:
# 50 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 47 users would have had final average_rating < 0
# 3 users would have had final average_rating >= 0
#
#
# 147 in-edge(s) would have been prevented:
# 111 bad rating(s), 36 good rating(s)
#
#
# 56 out-edge(s) would have been prevented:
# 12 bad rating(s), 44 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-11
# Effects of banning users in this month:
# 17 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 16 users would have had final average_rating < 0
# 1 users would have had final average_rating >= 0
#
#
# 41 in-edge(s) would have been prevented:
# 31 bad rating(s), 10 good rating(s)
#
#
# 17 out-edge(s) would have been prevented:
# 1 bad rating(s), 16 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-12
# Effects of banning users in this month:
# 23 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 23 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 52 in-edge(s) would have been prevented:
# 42 bad rating(s), 10 good rating(s)
#
#
# 15 out-edge(s) would have been prevented:
# 1 bad rating(s), 14 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-01
# Effects of banning users in this month:
# 21 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 19 users would have had final average_rating < 0
# 2 users would have had final average_rating >= 0
#
#
# 92 in-edge(s) would have been prevented:
# 59 bad rating(s), 33 good rating(s)
#
#
# 51 out-edge(s) would have been prevented:
# 19 bad rating(s), 32 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-02
# Effects of banning users in this month:
# 14 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 14 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 31 in-edge(s) would have been prevented:
# 25 bad rating(s), 6 good rating(s)
#
#
# 22 out-edge(s) would have been prevented:
# 2 bad rating(s), 20 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-03
# Effects of banning users in this month:
# 35 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 31 users would have had final average_rating < 0
# 4 users would have had final average_rating >= 0
#
#
# 248 in-edge(s) would have been prevented:
# 220 bad rating(s), 28 good rating(s)
#
#
# 423 out-edge(s) would have been prevented:
# 353 bad rating(s), 70 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-04
# Effects of banning users in this month:
# 15 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 13 users would have had final average_rating < 0
# 2 users would have had final average_rating >= 0
#
#
# 27 in-edge(s) would have been prevented:
# 23 bad rating(s), 4 good rating(s)
#
#
# 9 out-edge(s) would have been prevented:
# 3 bad rating(s), 6 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-05
# Effects of banning users in this month:
# 10 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 10 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 29 in-edge(s) would have been prevented:
# 25 bad rating(s), 4 good rating(s)
#
#
# 5 out-edge(s) would have been prevented:
# 0 bad rating(s), 5 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-06
# Effects of banning users in this month:
# 15 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 15 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 47 in-edge(s) would have been prevented:
# 39 bad rating(s), 8 good rating(s)
#
#
# 16 out-edge(s) would have been prevented:
# 0 bad rating(s), 16 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-07
# Effects of banning users in this month:
# 33 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 33 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 138 in-edge(s) would have been prevented:
# 86 bad rating(s), 52 good rating(s)
#
#
# 97 out-edge(s) would have been prevented:
# 22 bad rating(s), 75 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-08
# Effects of banning users in this month:
# 78 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 75 users would have had final average_rating < 0
# 3 users would have had final average_rating >= 0
#
#
# 1111 in-edge(s) would have been prevented:
# 619 bad rating(s), 492 good rating(s)
#
#
# 809 out-edge(s) would have been prevented:
# 291 bad rating(s), 518 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-09
# Effects of banning users in this month:
# 16 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 15 users would have had final average_rating < 0
# 1 users would have had final average_rating >= 0
#
#
# 56 in-edge(s) would have been prevented:
# 30 bad rating(s), 26 good rating(s)
#
#
# 43 out-edge(s) would have been prevented:
# 7 bad rating(s), 36 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-10
# Effects of banning users in this month:
# 15 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 14 users would have had final average_rating < 0
# 1 users would have had final average_rating >= 0
#
#
# 35 in-edge(s) would have been prevented:
# 22 bad rating(s), 13 good rating(s)
#
#
# 20 out-edge(s) would have been prevented:
# 2 bad rating(s), 18 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-11
# Effects of banning users in this month:
# 36 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 35 users would have had final average_rating < 0
# 1 users would have had final average_rating >= 0
#
#
# 127 in-edge(s) would have been prevented:
# 72 bad rating(s), 55 good rating(s)
#
#
# 73 out-edge(s) would have been prevented:
# 10 bad rating(s), 63 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-12
# Effects of banning users in this month:
# 88 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 85 users would have had final average_rating < 0
# 3 users would have had final average_rating >= 0
#
#
# 236 in-edge(s) would have been prevented:
# 177 bad rating(s), 59 good rating(s)
#
#
# 120 out-edge(s) would have been prevented:
# 59 bad rating(s), 61 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-01
# Effects of banning users in this month:
# 46 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 46 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 57 in-edge(s) would have been prevented:
# 57 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-02
# Effects of banning users in this month:
# 43 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 43 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 79 in-edge(s) would have been prevented:
# 67 bad rating(s), 12 good rating(s)
#
#
# 22 out-edge(s) would have been prevented:
# 9 bad rating(s), 13 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-03
# Effects of banning users in this month:
# 20 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 19 users would have had final average_rating < 0
# 1 users would have had final average_rating >= 0
#
#
# 58 in-edge(s) would have been prevented:
# 40 bad rating(s), 18 good rating(s)
#
#
# 44 out-edge(s) would have been prevented:
# 24 bad rating(s), 20 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-04
# Effects of banning users in this month:
# 14 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 14 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 45 in-edge(s) would have been prevented:
# 37 bad rating(s), 8 good rating(s)
#
#
# 11 out-edge(s) would have been prevented:
# 2 bad rating(s), 9 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-05
# Effects of banning users in this month:
# 8 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 6 users would have had final average_rating < 0
# 2 users would have had final average_rating >= 0
#
#
# 21 in-edge(s) would have been prevented:
# 18 bad rating(s), 3 good rating(s)
#
#
# 5 out-edge(s) would have been prevented:
# 2 bad rating(s), 3 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-06
# Effects of banning users in this month:
# 9 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 9 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 33 in-edge(s) would have been prevented:
# 24 bad rating(s), 9 good rating(s)
#
#
# 21 out-edge(s) would have been prevented:
# 0 bad rating(s), 21 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-07
# Effects of banning users in this month:
# 6 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 6 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 15 in-edge(s) would have been prevented:
# 11 bad rating(s), 4 good rating(s)
#
#
# 2 out-edge(s) would have been prevented:
# 0 bad rating(s), 2 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-08
# Effects of banning users in this month:
# 20 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 20 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 64 in-edge(s) would have been prevented:
# 45 bad rating(s), 19 good rating(s)
#
#
# 60 out-edge(s) would have been prevented:
# 20 bad rating(s), 40 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-09
# Effects of banning users in this month:
# 8 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 7 users would have had final average_rating < 0
# 1 users would have had final average_rating >= 0
#
#
# 15 in-edge(s) would have been prevented:
# 15 bad rating(s), 0 good rating(s)
#
#
# 1 out-edge(s) would have been prevented:
# 0 bad rating(s), 1 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-10
# Effects of banning users in this month:
# 5 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 5 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 11 in-edge(s) would have been prevented:
# 10 bad rating(s), 1 good rating(s)
#
#
# 3 out-edge(s) would have been prevented:
# 0 bad rating(s), 3 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-11
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2014-12
# Effects of banning users in this month:
# 6 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 6 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 11 in-edge(s) would have been prevented:
# 11 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-01
# Effects of banning users in this month:
# 4 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 3 users would have had final average_rating < 0
# 1 users would have had final average_rating >= 0
#
#
# 4 in-edge(s) would have been prevented:
# 4 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-02
# Effects of banning users in this month:
# 4 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 4 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 5 in-edge(s) would have been prevented:
# 5 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-03
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2015-04
# Effects of banning users in this month:
# 3 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 3 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 3 in-edge(s) would have been prevented:
# 3 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-05
# Effects of banning users in this month:
# 5 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 4 users would have had final average_rating < 0
# 1 users would have had final average_rating >= 0
#
#
# 7 in-edge(s) would have been prevented:
# 7 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-06
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2015-07
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 1 in-edge(s) would have been prevented:
# 1 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-08
# Effects of banning users in this month:
# 3 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 3 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 3 in-edge(s) would have been prevented:
# 3 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-09
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2015-10
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2015-11
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 1 in-edge(s) would have been prevented:
# 1 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-12
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 1 in-edge(s) would have been prevented:
# 1 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2016-01
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final average_rating < 0
# 0 users would have had final average_rating >= 0
#
#
# 1 in-edge(s) would have been prevented:
# 1 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Final simulation results:
# Final scores/ratings of banned users:
# 810 users would have had final average_rating < 0
# 34 users would have had final average_rating >= 0
#
#
# 3640 in-edge(s) would have been prevented:
# 2479 bad rating(s), 1161 good rating(s)
#
#
# 2318 out-edge(s) would have been prevented:
# 888 bad rating(s), 1430 good rating(s)

# %%
users_banned_average.to_csv('users_banned_average.csv')
in_edges_removed_average.to_csv('in_edges_removed_average.csv')
out_edges_removed_average.to_csv('out_edges_removed_average.csv')

# %% [markdown]
# ### Simulation Using Goodness Scores

# %%
users_banned_goodness, in_edges_removed_goodness, out_edges_removed_goodness = simulation('goodness', 0, True)
# Out:
# Running simulation of banning users based on goodness with threshold of 0
# ---------------------------------------------------------------------------
# Simulating for the month 2010-11
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2010-12
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2011-01
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2011-02
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2011-03
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 6 in-edge(s) would have been prevented:
# 5 bad rating(s), 1 good rating(s)
#
#
# 1 out-edge(s) would have been prevented:
# 0 bad rating(s), 1 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-04
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 2 in-edge(s) would have been prevented:
# 1 bad rating(s), 1 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-05
# Effects of banning users in this month:
# 9 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 9 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 48 in-edge(s) would have been prevented:
# 29 bad rating(s), 19 good rating(s)
#
#
# 24 out-edge(s) would have been prevented:
# 1 bad rating(s), 23 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-06
# Effects of banning users in this month:
# 18 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 17 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 76 in-edge(s) would have been prevented:
# 51 bad rating(s), 25 good rating(s)
#
#
# 50 out-edge(s) would have been prevented:
# 5 bad rating(s), 45 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-07
# Effects of banning users in this month:
# 5 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 5 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 26 in-edge(s) would have been prevented:
# 25 bad rating(s), 1 good rating(s)
#
#
# 1 out-edge(s) would have been prevented:
# 0 bad rating(s), 1 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-08
# Effects of banning users in this month:
# 3 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 3 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 8 in-edge(s) would have been prevented:
# 8 bad rating(s), 0 good rating(s)
#
#
# 2 out-edge(s) would have been prevented:
# 0 bad rating(s), 2 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-09
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2011-10
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 1 in-edge(s) would have been prevented:
# 1 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-11
# Effects of banning users in this month:
# 2 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 2 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 3 in-edge(s) would have been prevented:
# 2 bad rating(s), 1 good rating(s)
#
#
# 1 out-edge(s) would have been prevented:
# 0 bad rating(s), 1 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2011-12
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2012-01
# Effects of banning users in this month:
# 4 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 4 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 10 in-edge(s) would have been prevented:
# 10 bad rating(s), 0 good rating(s)
#
#
# 3 out-edge(s) would have been prevented:
# 1 bad rating(s), 2 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-02
# Effects of banning users in this month:
# 2 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 2 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 5 in-edge(s) would have been prevented:
# 4 bad rating(s), 1 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-03
# Effects of banning users in this month:
# 5 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 5 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 20 in-edge(s) would have been prevented:
# 15 bad rating(s), 5 good rating(s)
#
#
# 8 out-edge(s) would have been prevented:
# 0 bad rating(s), 8 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-04
# Effects of banning users in this month:
# 6 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 5 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 17 in-edge(s) would have been prevented:
# 15 bad rating(s), 2 good rating(s)
#
#
# 7 out-edge(s) would have been prevented:
# 0 bad rating(s), 7 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-05
# Effects of banning users in this month:
# 3 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 3 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 12 in-edge(s) would have been prevented:
# 11 bad rating(s), 1 good rating(s)
#
#
# 2 out-edge(s) would have been prevented:
# 0 bad rating(s), 2 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-06
# Effects of banning users in this month:
# 9 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 9 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 23 in-edge(s) would have been prevented:
# 19 bad rating(s), 4 good rating(s)
#
#
# 12 out-edge(s) would have been prevented:
# 1 bad rating(s), 11 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-07
# Effects of banning users in this month:
# 11 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 9 users would have had final goodness < 0
# 2 users would have had final goodness >= 0
#
#
# 61 in-edge(s) would have been prevented:
# 24 bad rating(s), 37 good rating(s)
#
#
# 55 out-edge(s) would have been prevented:
# 12 bad rating(s), 43 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-08
# Effects of banning users in this month:
# 16 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 14 users would have had final goodness < 0
# 2 users would have had final goodness >= 0
#
#
# 101 in-edge(s) would have been prevented:
# 74 bad rating(s), 27 good rating(s)
#
#
# 32 out-edge(s) would have been prevented:
# 3 bad rating(s), 29 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-09
# Effects of banning users in this month:
# 82 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 81 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 476 in-edge(s) would have been prevented:
# 301 bad rating(s), 175 good rating(s)
#
#
# 217 out-edge(s) would have been prevented:
# 32 bad rating(s), 185 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-10
# Effects of banning users in this month:
# 32 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 32 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 113 in-edge(s) would have been prevented:
# 82 bad rating(s), 31 good rating(s)
#
#
# 50 out-edge(s) would have been prevented:
# 11 bad rating(s), 39 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-11
# Effects of banning users in this month:
# 19 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 16 users would have had final goodness < 0
# 3 users would have had final goodness >= 0
#
#
# 45 in-edge(s) would have been prevented:
# 32 bad rating(s), 13 good rating(s)
#
#
# 21 out-edge(s) would have been prevented:
# 0 bad rating(s), 21 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2012-12
# Effects of banning users in this month:
# 23 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 22 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 46 in-edge(s) would have been prevented:
# 37 bad rating(s), 9 good rating(s)
#
#
# 14 out-edge(s) would have been prevented:
# 1 bad rating(s), 13 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-01
# Effects of banning users in this month:
# 20 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 18 users would have had final goodness < 0
# 2 users would have had final goodness >= 0
#
#
# 75 in-edge(s) would have been prevented:
# 53 bad rating(s), 22 good rating(s)
#
#
# 38 out-edge(s) would have been prevented:
# 18 bad rating(s), 20 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-02
# Effects of banning users in this month:
# 16 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 16 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 51 in-edge(s) would have been prevented:
# 30 bad rating(s), 21 good rating(s)
#
#
# 22 out-edge(s) would have been prevented:
# 2 bad rating(s), 20 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-03
# Effects of banning users in this month:
# 33 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 33 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 247 in-edge(s) would have been prevented:
# 219 bad rating(s), 28 good rating(s)
#
#
# 417 out-edge(s) would have been prevented:
# 352 bad rating(s), 65 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-04
# Effects of banning users in this month:
# 9 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 8 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 15 in-edge(s) would have been prevented:
# 13 bad rating(s), 2 good rating(s)
#
#
# 7 out-edge(s) would have been prevented:
# 2 bad rating(s), 5 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-05
# Effects of banning users in this month:
# 9 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 9 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 40 in-edge(s) would have been prevented:
# 35 bad rating(s), 5 good rating(s)
#
#
# 9 out-edge(s) would have been prevented:
# 0 bad rating(s), 9 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-06
# Effects of banning users in this month:
# 13 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 12 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 28 in-edge(s) would have been prevented:
# 21 bad rating(s), 7 good rating(s)
#
#
# 11 out-edge(s) would have been prevented:
# 0 bad rating(s), 11 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-07
# Effects of banning users in this month:
# 28 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 28 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 115 in-edge(s) would have been prevented:
# 78 bad rating(s), 37 good rating(s)
#
#
# 82 out-edge(s) would have been prevented:
# 21 bad rating(s), 61 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-08
# Effects of banning users in this month:
# 68 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 67 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 707 in-edge(s) would have been prevented:
# 518 bad rating(s), 189 good rating(s)
#
#
# 363 out-edge(s) would have been prevented:
# 170 bad rating(s), 193 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-09
# Effects of banning users in this month:
# 18 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 14 users would have had final goodness < 0
# 4 users would have had final goodness >= 0
#
#
# 60 in-edge(s) would have been prevented:
# 34 bad rating(s), 26 good rating(s)
#
#
# 43 out-edge(s) would have been prevented:
# 7 bad rating(s), 36 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-10
# Effects of banning users in this month:
# 14 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 14 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 26 in-edge(s) would have been prevented:
# 20 bad rating(s), 6 good rating(s)
#
#
# 10 out-edge(s) would have been prevented:
# 1 bad rating(s), 9 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-11
# Effects of banning users in this month:
# 38 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 34 users would have had final goodness < 0
# 4 users would have had final goodness >= 0
#
#
# 139 in-edge(s) would have been prevented:
# 74 bad rating(s), 65 good rating(s)
#
#
# 78 out-edge(s) would have been prevented:
# 10 bad rating(s), 68 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2013-12
# Effects of banning users in this month:
# 84 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 84 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 209 in-edge(s) would have been prevented:
# 169 bad rating(s), 40 good rating(s)
#
#
# 93 out-edge(s) would have been prevented:
# 52 bad rating(s), 41 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-01
# Effects of banning users in this month:
# 46 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 46 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 57 in-edge(s) would have been prevented:
# 57 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-02
# Effects of banning users in this month:
# 44 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 44 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 83 in-edge(s) would have been prevented:
# 71 bad rating(s), 12 good rating(s)
#
#
# 19 out-edge(s) would have been prevented:
# 7 bad rating(s), 12 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-03
# Effects of banning users in this month:
# 18 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 17 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 43 in-edge(s) would have been prevented:
# 34 bad rating(s), 9 good rating(s)
#
#
# 13 out-edge(s) would have been prevented:
# 4 bad rating(s), 9 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-04
# Effects of banning users in this month:
# 14 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 14 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 47 in-edge(s) would have been prevented:
# 38 bad rating(s), 9 good rating(s)
#
#
# 15 out-edge(s) would have been prevented:
# 4 bad rating(s), 11 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-05
# Effects of banning users in this month:
# 7 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 7 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 19 in-edge(s) would have been prevented:
# 16 bad rating(s), 3 good rating(s)
#
#
# 5 out-edge(s) would have been prevented:
# 2 bad rating(s), 3 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-06
# Effects of banning users in this month:
# 9 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 9 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 33 in-edge(s) would have been prevented:
# 24 bad rating(s), 9 good rating(s)
#
#
# 21 out-edge(s) would have been prevented:
# 0 bad rating(s), 21 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-07
# Effects of banning users in this month:
# 5 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 4 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 12 in-edge(s) would have been prevented:
# 10 bad rating(s), 2 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-08
# Effects of banning users in this month:
# 22 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 21 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 103 in-edge(s) would have been prevented:
# 59 bad rating(s), 44 good rating(s)
#
#
# 89 out-edge(s) would have been prevented:
# 27 bad rating(s), 62 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-09
# Effects of banning users in this month:
# 6 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 6 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 8 in-edge(s) would have been prevented:
# 8 bad rating(s), 0 good rating(s)
#
#
# 1 out-edge(s) would have been prevented:
# 0 bad rating(s), 1 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-10
# Effects of banning users in this month:
# 6 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 5 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 10 in-edge(s) would have been prevented:
# 9 bad rating(s), 1 good rating(s)
#
#
# 3 out-edge(s) would have been prevented:
# 0 bad rating(s), 3 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2014-11
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2014-12
# Effects of banning users in this month:
# 7 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 7 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 12 in-edge(s) would have been prevented:
# 12 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-01
# Effects of banning users in this month:
# 5 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 4 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 5 in-edge(s) would have been prevented:
# 5 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-02
# Effects of banning users in this month:
# 4 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 4 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 5 in-edge(s) would have been prevented:
# 5 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-03
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 1 in-edge(s) would have been prevented:
# 1 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-04
# Effects of banning users in this month:
# 3 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 3 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 3 in-edge(s) would have been prevented:
# 3 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-05
# Effects of banning users in this month:
# 5 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 4 users would have had final goodness < 0
# 1 users would have had final goodness >= 0
#
#
# 7 in-edge(s) would have been prevented:
# 7 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-06
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2015-07
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 1 in-edge(s) would have been prevented:
# 1 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-08
# Effects of banning users in this month:
# 3 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 3 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 3 in-edge(s) would have been prevented:
# 3 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-09
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2015-10
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2015-11
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 1 in-edge(s) would have been prevented:
# 1 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Simulating for the month 2015-12
# Effects of banning users in this month:
# 0 bad user(s) were banned
# Simulation of this month would not have affected the future
# ---------------------------------------------------------------------------
# Simulating for the month 2016-01
# Effects of banning users in this month:
# 1 bad user(s) were banned
# Final scores/ratings of banned users in this month:
# 1 users would have had final goodness < 0
# 0 users would have had final goodness >= 0
#
#
# 1 in-edge(s) would have been prevented:
# 1 bad rating(s), 0 good rating(s)
#
#
# 0 out-edge(s) would have been prevented:
# 0 bad rating(s), 0 good rating(s)
# ---------------------------------------------------------------------------
# Final simulation results:
# Final scores/ratings of banned users:
# 780 users would have had final goodness < 0
# 30 users would have had final goodness >= 0
#
#
# 3265 in-edge(s) would have been prevented:
# 2375 bad rating(s), 890 good rating(s)
#
#
# 1839 out-edge(s) would have been prevented:
# 746 bad rating(s), 1093 good rating(s)

# %%
users_banned_goodness.to_csv('users_banned_goodness.csv')
in_edges_removed_goodness.to_csv('in_edges_removed_goodness.csv')
out_edges_removed_goodness.to_csv('out_edges_removed_goodness.csv')

# %% [markdown]
# ## Results

# %%
sb.set_style('darkgrid')

# %%
users_banned_average = pd.read_csv('users_banned_average.csv')
in_edges_removed_average = pd.read_csv('in_edges_removed_average.csv')
out_edges_removed_average = pd.read_csv('out_edges_removed_average.csv')
users_banned_goodness = pd.read_csv('users_banned_goodness.csv')
in_edges_removed_goodness = pd.read_csv('in_edges_removed_goodness.csv')
out_edges_removed_goodness = pd.read_csv('out_edges_removed_goodness.csv')

# %% [markdown]
# First, the new columns are added to ```users_banned_goodness``` and ```users_banned_average``` to indicate whether the users had a final score/average rating below or above threshold.

# %%
users_banned_goodness['type_rating'] = users_banned_goodness.apply(lambda row:
    'bad' if row['final_average_rating'] < 0 else 'good',
    axis=1
)
users_banned_goodness['type_goodness'] = users_banned_goodness.apply(lambda row:
    'bad' if row['final_goodness'] < 0 else 'good',
    axis=1
)

# %%
users_banned_average['type_rating'] = users_banned_average.apply(lambda row:
    'bad' if row['final_average_rating'] < 0 else 'good',
    axis=1
)
users_banned_average['type_goodness'] = users_banned_average.apply(lambda row:
    'bad' if row['final_goodness'] < 0 else 'good',
    axis=1
)

# %% [markdown]
# ### Final Goodness Scores of the Users

# %%
title_size = 24
xy_label_size = 22
xy_ticks_size = 16
annotation_size =18

# %%
plt.figure(figsize=(16, 8))

num_bad = (len(users_banned_average[users_banned_average['type_goodness'] == 'bad']) / len(users_banned_average['type_goodness']))*100
num_good = (len(users_banned_average[users_banned_average['type_goodness'] == 'good']) / len(users_banned_average['type_goodness']))*100
pct_bad = '{:.2f}%'.format(num_bad)
pct_good = '{:.2f}%'.format(num_good)

col_labels = [pct_bad, pct_good]
plt.subplot(121)
ax = sb.countplot(data=users_banned_average,
                  x='type_goodness',
                  order=users_banned_average['type_goodness'].value_counts().index)

for p, label in zip(ax.patches, col_labels):
     ax.annotate(label, (p.get_x()+0.35, p.get_height()+0.5), fontsize=annotation_size)

plt.title('Final Goodness Score - \nUsers banned using average rating', fontsize=title_size)
plt.xlabel('User type', fontsize=xy_label_size)
plt.ylabel('Count', fontsize=xy_label_size)
plt.xticks(fontsize=xy_ticks_size)
plt.yticks(fontsize=xy_ticks_size)

num_bad = (len(users_banned_goodness[users_banned_goodness['type_goodness'] == 'bad']) / len(users_banned_goodness['type_goodness']))*100
num_good = (len(users_banned_goodness[users_banned_goodness['type_goodness'] == 'good']) / len(users_banned_goodness['type_goodness']))*100
pct_bad = '{:.2f}%'.format(num_bad)
pct_good = '{:.2f}%'.format(num_good)

col_labels = [pct_bad, pct_good]
plt.subplot(122)
ax = sb.countplot(data=users_banned_goodness,
                  x='type_goodness',
                  order=users_banned_goodness['type_goodness'].value_counts().index)

for p, label in zip(ax.patches, col_labels):
     ax.annotate(label, (p.get_x()+0.35, p.get_height()+0.5), fontsize=annotation_size)

plt.title('Final Goodness Score - \nUsers banned using goodness score', fontsize=title_size)
plt.xlabel('User type', fontsize=xy_label_size)
plt.ylabel('Count', fontsize=xy_label_size)
plt.xticks(fontsize=xy_ticks_size)
plt.yticks(fontsize=xy_ticks_size)
plt.show()

# %%
plt.figure(figsize=(16, 8))
plt.subplot(121)
sb.histplot(data=users_banned_average,x='final_goodness')
plt.title('Final Goodness Score - Users banned using average rating')
plt.subplot(122)
sb.histplot(data=users_banned_goodness, x='final_goodness')
plt.title('Final Goodness Score - Users banned using goodness score')
plt.show()

# %% [markdown]
# ### Final Average Ratings of the Users

# %%
plt.figure(figsize=(16, 8))

num_bad = (len(users_banned_average[users_banned_average['type_rating'] == 'bad']) / len(users_banned_average['type_rating']))*100
num_good = (len(users_banned_average[users_banned_average['type_rating'] == 'good']) / len(users_banned_average['type_rating']))*100
pct_bad = '{:.2f}%'.format(num_bad)
pct_good = '{:.2f}%'.format(num_good)

col_labels = [pct_bad, pct_good]
plt.subplot(121)
ax = sb.countplot(data=users_banned_average,
                  x='type_rating',
                  order=users_banned_average['type_rating'].value_counts().index)

for p, label in zip(ax.patches, col_labels):
     ax.annotate(label, (p.get_x()+0.35, p.get_height()+0.2))

plt.title('Final Average Rating - Users banned using average rating', fontsize=20)


num_bad = (len(users_banned_goodness[users_banned_goodness['type_rating'] == 'bad']) / len(users_banned_goodness['type_rating']))*100
num_good = (len(users_banned_goodness[users_banned_goodness['type_rating'] == 'good']) / len(users_banned_goodness['type_rating']))*100
pct_bad = '{:.2f}%'.format(num_bad)
pct_good = '{:.2f}%'.format(num_good)

col_labels = [pct_bad, pct_good]
plt.subplot(122)
ax = sb.countplot(data=users_banned_goodness,
                  x='type_rating',
                  order=users_banned_goodness['type_rating'].value_counts().index)

for p, label in zip(ax.patches, col_labels):
     ax.annotate(label, (p.get_x()+0.35, p.get_height()+0.2))

plt.title('Final Average Rating - Users banned using goodness score', fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a647337bb513> in <module>
# ----> 1 plt.figure(figsize=(16, 8))
#       2
#       3 num_bad = (len(users_banned_average[users_banned_average['type_rating'] == 'bad']) / len(users_banned_average['type_rating']))*100
#       4 num_good = (len(users_banned_average[users_banned_average['type_rating'] == 'good']) / len(users_banned_average['type_rating']))*100
#       5 pct_bad = '{:.2f}%'.format(num_bad)
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(16, 8))
plt.subplot(121)
sb.histplot(data=users_banned_average, x='final_average_rating')
plt.title('Final Average Rating - Users banned using average rating')
plt.subplot(122)
sb.histplot(data=users_banned_goodness, x='final_average_rating')
plt.title('Final Average Rating - Users banned using goodness score')
plt.show()

# %% [markdown]
# ### Ratings of the In-Edges Removed

# %%
plt.figure(figsize=(16, 8))
plt.subplot(121)
sb.histplot(data=in_edges_removed_average, x='rating')
plt.title('Rating of In-edges Removed - Users banned using average rating')
plt.subplot(122)
sb.histplot(data=in_edges_removed_goodness, x='rating')
plt.title('Rating of In-edges Removed - Users banned using goodness score')
plt.show()

# %% [markdown]
# ### Ratings of Out-Edges Removed

# %%
plt.figure(figsize=(16, 8))
plt.subplot(121)
sb.histplot(data=out_edges_removed_average, x='rating')
plt.title('Rating of Out-edges Removed - Users banned using average rating')
plt.subplot(122)
sb.histplot(data=out_edges_removed_goodness, x='rating')
plt.title('Rating of Out-edges Removed - Users banned using goodness score')
plt.show()
