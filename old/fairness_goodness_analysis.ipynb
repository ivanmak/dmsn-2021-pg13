# %%
from temporal_networkx import TemporalDiGraph
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import math
from datetime import datetime, timedelta
from copy import deepcopy

# %%
temporal_graph = TemporalDiGraph(pd.read_csv('./soc-sign-bitcoinotc.csv', header=None))

# %% [markdown]
# # Calculating Fairness and Goodness Scores for Each Rolling Month

# %% [markdown]
# The following code generates DiGraph of the trust network for each rolling month, i.e. from the first month of the data set to each month covered by the data set, and then saves the results in separate CSV files.

# %%
user_fairness_by_month = {}
user_goodness_by_month = {}
user_average_ratings_by_month = {}
user_bad_ratings_count_by_month = {}
user_good_ratings_count_by_month = {}
sep = '---------------------------------------------------------------------------'
first_month = None

for month in temporal_graph.get_all_months():
    # Loop through all months
    if first_month is None:
        first_month = str(month)


    # Generate a DiGraph from the first months till the current month
    print(f'Calculating fairness and goodness for the period between {str(first_month)} and {str(month)}')
    G = temporal_graph.get_DiGraph(str(first_month), str(month), run_REV2=True)
    nodes = G.nodes(data=True)
    edges = G.edges()
    print(f'This period contains {len(nodes)} nodes and {len(edges)} edges')
    
    # Loop through all nodes
    for node in nodes:
        user_id = node[0]

        # Fairness and goodness scores were calculated by REV2
        # when the graph was generated
        user_fairness = node[1]['fairness']
        user_goodness = node[1]['goodness']
        user_average_ratings = 0.0
        user_bad_ratings_count = 0
        user_good_ratings_count = 0
        
        in_edges = G.in_edges(user_id, data=True)

        # Loop through the in-edges of this node to
        # calculate average ratings and count good/bad ratings
        for edge in in_edges:
            user_average_ratings = user_average_ratings + edge[2]['weight']

            if edge[2]['weight'] > 0.0:
                user_good_ratings_count = user_good_ratings_count + 1
            elif edge[2]['weight'] < 0.0:
                user_bad_ratings_count = user_bad_ratings_count + 1

        if len(in_edges) > 0:
            user_average_ratings = user_average_ratings / len(in_edges)

        # Save the results into dictionaries
        if user_id not in user_fairness_by_month:
            user_fairness_by_month[user_id] = {}

        if user_id not in user_goodness_by_month: 
            user_goodness_by_month[user_id] = {}

        if user_id not in user_average_ratings_by_month:
            user_average_ratings_by_month[user_id] = {}

        if user_id not in user_bad_ratings_count_by_month:
            user_bad_ratings_count_by_month[user_id] = {}

        if user_id not in user_good_ratings_count_by_month:
            user_good_ratings_count_by_month[user_id] = {}

        user_fairness_by_month[user_id][str(month)] = user_fairness
        user_goodness_by_month[user_id][str(month)] = user_goodness
        user_average_ratings_by_month[user_id][str(month)] = user_average_ratings
        user_bad_ratings_count_by_month[user_id][str(month)] = user_bad_ratings_count
        user_good_ratings_count_by_month[user_id][str(month)] = user_good_ratings_count

    print(sep)
    #bad_users_by_month[str(month)] = [n for n in G.nodes(data=True) if n[1]['goodness'] < 0]
# Out:
# Calculating fairness and goodness for the period between 2010-11 and 2010-11
# This period contains 26 nodes and 60 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2010-12
# This period contains 55 nodes and 142 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2011-01
# This period contains 84 nodes and 241 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2011-02
# This period contains 137 nodes and 486 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2011-03
# This period contains 186 nodes and 680 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2011-04
# This period contains 319 nodes and 1239 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2011-05
# This period contains 721 nodes and 3150 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2011-06
# This period contains 1240 nodes and 5583 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2011-07
# This period contains 1334 nodes and 6141 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2011-08
# This period contains 1407 nodes and 6635 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2011-09
# This period contains 1452 nodes and 6917 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2011-10
# This period contains 1501 nodes and 7174 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2011-11
# This period contains 1563 nodes and 7470 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2011-12
# This period contains 1637 nodes and 7900 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2012-01
# This period contains 1703 nodes and 8287 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2012-02
# This period contains 1774 nodes and 8778 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2012-03
# This period contains 1877 nodes and 9341 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2012-04
# This period contains 1961 nodes and 9905 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2012-05
# This period contains 2065 nodes and 10517 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2012-06
# This period contains 2189 nodes and 11297 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2012-07
# This period contains 2306 nodes and 12204 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2012-08
# This period contains 2453 nodes and 13108 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2012-09
# This period contains 2643 nodes and 14261 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2012-10
# This period contains 2838 nodes and 15349 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2012-11
# This period contains 3000 nodes and 16340 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2012-12
# This period contains 3162 nodes and 17332 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2013-01
# This period contains 3314 nodes and 18228 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2013-02
# This period contains 3455 nodes and 18994 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2013-03
# This period contains 3721 nodes and 20420 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2013-04
# This period contains 4078 nodes and 22237 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2013-05
# This period contains 4239 nodes and 23354 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2013-06
# This period contains 4379 nodes and 24322 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2013-07
# This period contains 4511 nodes and 25413 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2013-08
# This period contains 4720 nodes and 27347 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2013-09
# This period contains 4787 nodes and 27951 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2013-10
# This period contains 4877 nodes and 28589 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2013-11
# This period contains 5006 nodes and 29516 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2013-12
# This period contains 5161 nodes and 30314 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2014-01
# This period contains 5253 nodes and 30781 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2014-02
# This period contains 5347 nodes and 31307 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2014-03
# This period contains 5391 nodes and 31637 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2014-04
# This period contains 5452 nodes and 32181 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2014-05
# This period contains 5498 nodes and 32539 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2014-06
# This period contains 5554 nodes and 32937 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2014-07
# This period contains 5593 nodes and 33256 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2014-08
# This period contains 5643 nodes and 33688 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2014-09
# This period contains 5683 nodes and 33926 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2014-10
# This period contains 5708 nodes and 34156 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2014-11
# This period contains 5731 nodes and 34353 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2014-12
# This period contains 5753 nodes and 34539 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2015-01
# This period contains 5770 nodes and 34687 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2015-02
# This period contains 5795 nodes and 34806 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2015-03
# This period contains 5804 nodes and 34893 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2015-04
# This period contains 5814 nodes and 34989 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2015-05
# This period contains 5832 nodes and 35150 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2015-06
# This period contains 5841 nodes and 35240 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2015-07
# This period contains 5850 nodes and 35305 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2015-08
# This period contains 5862 nodes and 35385 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2015-09
# This period contains 5867 nodes and 35441 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2015-10
# This period contains 5871 nodes and 35479 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2015-11
# This period contains 5875 nodes and 35510 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2015-12
# This period contains 5879 nodes and 35550 edges
# ---------------------------------------------------------------------------
# Calculating fairness and goodness for the period between 2010-11 and 2016-01
# This period contains 5881 nodes and 35592 edges
# ---------------------------------------------------------------------------

# %%
fairness_df = pd.DataFrame.from_dict(user_fairness_by_month, orient='index')
goodness_df = pd.DataFrame.from_dict(user_goodness_by_month, orient='index')
average_ratings_df = pd.DataFrame.from_dict(user_average_ratings_by_month, orient='index')
bad_ratings_df = pd.DataFrame.from_dict(user_bad_ratings_count_by_month, orient='index')
good_ratings_df = pd.DataFrame.from_dict(user_good_ratings_count_by_month, orient='index')

# %%
fairness_df.to_csv('./user_fairness.csv')
goodness_df.to_csv('./user_goodness.csv')
average_ratings_df.to_csv('./user_average_ratings.csv')
bad_ratings_df.to_csv('./user_bad_ratings.csv')
good_ratings_df.to_csv('./user_good_ratings.csv')

# %%
fairness_df = pd.read_csv('./user_fairness.csv', index_col=0)
goodness_df = pd.read_csv('./user_goodness.csv', index_col=0)
average_ratings_df = pd.read_csv('./user_average_ratings.csv', index_col=0)
bad_ratings_df = pd.read_csv('./user_bad_ratings.csv', index_col=0)
good_ratings_df = pd.read_csv('./user_good_ratings.csv', index_col=0)

# %% [markdown]
# # Inspecting 'Bad' Users

# %% [markdown]
# After examining the scores, 2011-05 is the first month in the dataset with more than 10 'bad' users in terms of the REV2 goodness score.
#
# The variable ```month``` can be changed to inspect other months covered by the data set.

# %%
month = '2011-05'
month_df = goodness_df[[month]].dropna()
month_df = month_df.rename(columns={month: 'goodness'})

print(f"""
In the month {month}, there are {len(month_df)} users:
Number of users with goodness score > 0: {len(month_df[month_df['goodness'] > 0])}
Number of users with goodness score = 0: {len(month_df[month_df['goodness'] == 0])}
Number of users with goodness score < 0: {len(month_df[month_df['goodness'] < 0])}
""")
# Out:
# In the month 2011-05, there are 721 users:
# Number of users with goodness score > 0: 680
# Number of users with goodness score = 0: 30
# Number of users with goodness score < 0: 11

# %% [markdown]
# The following blocks inspect bad users (with a goodness score lower than 0.0) in the particular month, along with their average ratings in the month

# %%
goodness_threshold = 0

# %%
print(f"""
{len(month_df[month_df['goodness'] < goodness_threshold])} users with goodness score < {goodness_threshold} in the month {month}, and their average ratings:

{month_df[month_df['goodness'] < goodness_threshold].join(average_ratings_df[[month]]).rename(columns={month:'average_ratings'})}
""")
# Out:
# 11 users with goodness score < 0 in the month 2011-05, and their average ratings:
#
#      goodness  average_ratings
# 179 -0.233185        -0.428571
# 310 -1.000000        -5.142857
# 315 -1.000000        -4.500000
# 410 -1.000000        -6.000000
# 467 -1.000000        -3.750000
# 463 -0.239263        -1.000000
# 472 -1.000000        -3.733333
# 512 -1.000000        -1.750000
# 594 -1.000000        -2.250000
# 672 -1.000000        -4.666667
# 766 -1.000000       -10.000000

# %%
month_dt = datetime.strptime(month, '%Y-%m')
next_month_dt = (month_dt + timedelta(days=31)).replace(day=1)
next_month = next_month_dt.strftime('%Y-%m')

# %%
user_to_be_banned = 766
print(f"""
In the month {month}, user {user_to_be_banned} had a goodness score of {goodness_df.loc[user_to_be_banned][month]} and an average rating of {average_ratings_df.loc[user_to_be_banned][month]}.

In the next month, {next_month}, the user had a goodness score of {goodness_df.loc[user_to_be_banned][next_month]} and an average rating of {average_ratings_df.loc[user_to_be_banned][next_month]}.
""")
# Out:
# In the month 2011-05, user 766 had a goodness score of -1.0 and an average rating of -10.0.
#
# In the next month, 2011-06, the user had a goodness score of -1.0 and an average rating of -10.0.

# %% [markdown]
# # Simulation of Banning Bad Users

# %% [markdown]
# This method simulates the effect of banning a specific user, by retrieving the in-edges that will be removed in a counter-factual future after the user was banned.
#
# The method will return a dictionary of the counts of in-edges of different ratings if the user would have received ratings, or a boolean value of False if in reality the user did not receive further ratings, meaning banning the user would not have changed the future.
#
# This method would also be used in a later section where banning bad users on a monthly basis is simulated.

# %%
def ban_user(tG: TemporalDiGraph, user_to_be_banned: int, month: str, verbose: bool):
    num_in_edges_dropped = 0
    num_out_edges_dropped = 0
    in_edges_dropped = {}
    out_edges_dropped = {}

    for m in tG.get_all_months():
        if str(m) <= month:
            continue

        month_df = tG.get_df(str(m))
        user_in_edges = month_df[month_df['target'] == user_to_be_banned]
        user_out_edges = month_df[month_df['source'] == user_to_be_banned]

        num_in_edges_dropped = num_in_edges_dropped + len(user_in_edges)
        num_out_edges_dropped  = num_out_edges_dropped + len(user_out_edges)

        if num_in_edges_dropped + num_out_edges_dropped > 0:

            if verbose:

                if len(user_in_edges) > 0:
                    print(f"The following in-edges will be dropped in the month {m}:")
                    print(user_in_edges)
                    print('\n')

                if len(user_out_edges) > 0:
                    print(f"The following out-edges will be dropped in the month {m}:")
                    print(user_out_edges)
                    print('\n')

            for rating in user_in_edges['rating'].to_list():
                if rating not in in_edges_dropped:
                    in_edges_dropped[rating] = 1
                else:
                    in_edges_dropped[rating] = in_edges_dropped[rating] + 1

            for rating in user_out_edges['rating'].to_list():
                if rating not in out_edges_dropped:
                    out_edges_dropped[rating] = 1
                else:
                    out_edges_dropped[rating] = out_edges_dropped[rating] + 1

    if num_in_edges_dropped + num_out_edges_dropped == 0:
        # The future was not changed
        return False, False
    else:
        # The future was changed
        if verbose:
            if num_in_edges_dropped > 0:
                print('After banning this user, the following in-edges to this user would be prevented:')
                for k in sorted(in_edges_dropped):
                    print(f'{k}: {in_edges_dropped[k]} edges')

            if num_out_edges_dropped > 0:
                print('After banning this user, the following out-edges from this user would be prevented:')
                for k in sorted(out_edges_dropped):
                    print(f'{k}: {out_edges_dropped[k]} edges')
    
    return in_edges_dropped, out_edges_dropped

# %% [markdown]
# The following sections simulates how banning "bad users" in a given month would change the future in a counter-factual world.

# %%
month = '2011-06'
month_df = goodness_df[[month]].dropna()
month_df = month_df.rename(columns={month: 'goodness'})

bad_users = month_df[month_df['goodness'] < goodness_threshold].index.to_list()

# %%
sep = '---------------------------------------------------------------------------'
all_in_edges_dropped = {}
all_out_edges_dropped = {}
user_no_future_ratings = []
for bad_user in bad_users:
    print(f'''
Simulating banning the user {bad_user}
The user had a goodness score of {goodness_df.loc[bad_user][month]} in {month}
    ''')
    in_edges_dropped, out_edges_dropped = ban_user(temporal_graph, bad_user, month, verbose=True)
    
    if in_edges_dropped or out_edges_dropped:

        for k, v in in_edges_dropped.items():
            if k not in all_in_edges_dropped:
                all_in_edges_dropped[k] = v
            else:
                all_in_edges_dropped[k] = all_in_edges_dropped[k] + v

        for k, v in out_edges_dropped.items():
            if k not in all_out_edges_dropped:
                all_out_edges_dropped[k] = v
            else:
                all_out_edges_dropped[k] = all_out_edges_dropped[k] + v
    else:
        user_no_future_ratings.append(bad_user)
    print(sep)

print(f'''
The following {len(user_no_future_ratings)} users did not receive ratings after the month {month}
{', '.join([str(x) for x in user_no_future_ratings])}
''')
# Out:
# Simulating banning the user 179
# The user had a goodness score of -0.2072038132260703 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 310
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 315
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 410
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 467
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 463
# The user had a goodness score of -0.2559907854115311 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 472
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 512
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 594
# The user had a goodness score of -0.8881203445662448 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 672
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 726
# The user had a goodness score of -0.6998487738362246 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 766
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 787
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 805
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 895
# The user had a goodness score of -0.1988341242511545 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 906
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 957
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 984
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 1074
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 1099
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 1116
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 1139
# The user had a goodness score of -1.0 in 2011-06
#
# The following in-edges will be dropped in the month 2011-07:
#                      source  target  rating
# time
# 2011-07-18 03:38:50    1340    1139     -10
#
#
# After banning this user, the following in-edges to this user would be prevented:
# -10: 1 edges
# ---------------------------------------------------------------------------
#
# Simulating banning the user 1140
# The user had a goodness score of -1.0 in 2011-06
#
# The following in-edges will be dropped in the month 2011-07:
#                      source  target  rating
# time
# 2011-07-18 03:41:56    1340    1140     -10
#
#
# After banning this user, the following in-edges to this user would be prevented:
# -10: 1 edges
# ---------------------------------------------------------------------------
#
# Simulating banning the user 1143
# The user had a goodness score of -1.0 in 2011-06
#
# The following in-edges will be dropped in the month 2011-07:
#                      source  target  rating
# time
# 2011-07-18 03:42:07    1340    1143     -10
#
#
# The following in-edges will be dropped in the month 2011-08:
#                      source  target  rating
# time
# 2011-08-28 04:04:47     309    1143     -10
#
#
# After banning this user, the following in-edges to this user would be prevented:
# -10: 2 edges
# ---------------------------------------------------------------------------
#
# Simulating banning the user 1145
# The user had a goodness score of -1.0 in 2011-06
#
# The following in-edges will be dropped in the month 2011-08:
#                      source  target  rating
# time
# 2011-08-28 04:04:52     309    1145     -10
#
#
# After banning this user, the following in-edges to this user would be prevented:
# -10: 1 edges
# ---------------------------------------------------------------------------
#
# Simulating banning the user 1197
# The user had a goodness score of -0.4039832355724131 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 1211
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# Simulating banning the user 1277
# The user had a goodness score of -1.0 in 2011-06
#
# The following in-edges will be dropped in the month 2011-07:
#                      source  target  rating
# time
# 2011-07-02 19:33:42    1291    1277      10
# 2011-07-02 21:35:54    1293    1277       4
# 2011-07-08 17:42:52     908    1277       2
#
#
# The following out-edges will be dropped in the month 2011-07:
#                      source  target  rating
# time
# 2011-07-02 21:16:20    1277    1293       1
# 2011-07-02 21:17:04    1277     908       1
# 2011-07-02 21:19:24    1277     135     -10
# 2011-07-02 21:19:48    1277    1291      10
# 2011-07-02 21:20:44    1277     905       2
# 2011-07-04 13:53:42    1277    1268       2
# 2011-07-07 15:41:03    1277     832     -10
#
#
# The following in-edges will be dropped in the month 2012-12:
#                      source  target  rating
# time
# 2012-12-09 02:39:40     265    1277       1
#
#
# The following out-edges will be dropped in the month 2012-12:
#                      source  target  rating
# time
# 2012-12-10 18:10:31    1277     265       1
#
#
# The following in-edges will be dropped in the month 2013-01:
#                      source  target  rating
# time
# 2013-01-21 21:40:26      17    1277       1
#
#
# The following in-edges will be dropped in the month 2013-08:
#                      source  target  rating
# time
# 2013-08-23 09:52:06    3129    1277       1
#
#
# The following in-edges will be dropped in the month 2013-12:
#                      source  target  rating
# time
# 2013-12-11 02:23:59    4899    1277     -10
# 2013-12-11 04:33:52     361    1277      -1
#
#
# After banning this user, the following in-edges to this user would be prevented:
# -10: 1 edges
# -1: 1 edges
# 1: 3 edges
# 2: 1 edges
# 4: 1 edges
# 10: 1 edges
# After banning this user, the following out-edges from this user would be prevented:
# -10: 2 edges
# 1: 3 edges
# 2: 2 edges
# 10: 1 edges
# ---------------------------------------------------------------------------
#
# Simulating banning the user 713
# The user had a goodness score of -1.0 in 2011-06
#
# ---------------------------------------------------------------------------
#
# The following 24 users did not receive ratings after the month 2011-06
# 179, 310, 315, 410, 467, 463, 472, 512, 594, 672, 726, 766, 787, 805, 895, 906, 957, 984, 1074, 1099, 1116, 1197, 1211, 713

# %% [markdown]
# After banning all bad users in the given month, the counter-factual future would have been changed as the following.

# %%
print(f"""
After banning users with goodness score < {goodness_threshold} identified in the month {month}, the following in-edges would be prevented:
""")
for k in sorted(all_in_edges_dropped):
    print(f'{k}: {all_in_edges_dropped[k]} edges')

print('\nAnd the following out-edges would be prevented:')
for k in sorted(all_out_edges_dropped):
    print(f'{k}: {all_out_edges_dropped[k]} edges')
# Out:
# After banning users with goodness score < 0 identified in the month 2011-06, the following in-edges would be prevented:
#
# -10: 6 edges
# -1: 1 edges
# 1: 3 edges
# 2: 1 edges
# 4: 1 edges
# 10: 1 edges
#
# And the following out-edges would be prevented:
# -10: 2 edges
# 1: 3 edges
# 2: 2 edges
# 10: 1 edges

# %% [markdown]
# # Simulating Banning Bad Users At the End of Each Month

# %% [markdown]
# ## Banning Based on Goodness Scores

# %% [markdown]
# This section simulates how the future would have been changed if "bad users" are banned on a monthly basis according to their goodness scores.
#
# The effect of banning bad users are retained in each iteration. If a user is banned after a particular month, any in-edges to that user would be removed when goodness scores are calculated in subsequent iterations. Also, their out-edges would also be dropped to simulate a complete ban from the platform.

# %%
goodness_threshold = 0.0
users_banned = [-1, -2]
first_month = None
users_band_by_months = {}
all_in_edges_dropped = {}
all_out_edges_dropped = {}
user_no_future_ratings = {}
sep = '---------------------------------------------------------------------------'

for month in temporal_graph.get_all_months():
    month = str(month)
    month_dt = datetime.strptime(month, '%Y-%m')
    next_month_dt = (month_dt + timedelta(days=31)).replace(day=1)
    next_month = next_month_dt.strftime('%Y-%m')

    if month not in all_in_edges_dropped:
        all_in_edges_dropped[month] = {}
        for i in range(-10, 11):
            all_in_edges_dropped[month][i] = 0
    if month not in all_out_edges_dropped:
        all_out_edges_dropped[month] = {} 
        for i in range(-10, 11):
            all_out_edges_dropped[month][i] = 0
    if month not in user_no_future_ratings:
        user_no_future_ratings[month] = []
    if month not in users_band_by_months:
        users_band_by_months[month] = deepcopy(users_banned)

    if first_month is None:
        first_month = month

    print(f'Simulating for the month {month}')

    # Create a new directed graph for simulation in each iteration
    simulation_graph = deepcopy(temporal_graph)#, first_month, str(m)) 

    # Remove users that were already banned from simulation_graph
    # if len(users_banned) > 0:
    #     simulation_graph.df = simulation_graph.df.drop(
    #         simulation_graph.df.query(f"target in ({','.join([str(x) for x in users_banned])})").index
    #     )
    for k in users_band_by_months:
        if k < month:
            # Only drop the in-edges from the current month
            simulation_graph.df = simulation_graph.df.drop(
                simulation_graph.df[simulation_graph.df.index > k]
                .query(f"target in ({','.join([str(x) for x in users_band_by_months[k]])})").index
            )
            simulation_graph.df = simulation_graph.df.drop(
                simulation_graph.df[simulation_graph.df.index > k]
                .query(f"source in ({','.join([str(x) for x in users_band_by_months[k]])})").index
            )
    
    G = simulation_graph.get_DiGraph(first_month, month, run_REV2=True)

    # Find out what users to ban in each month
    bad_users = [ n[0] for n in G.nodes(data=True) if n[1]['goodness'] < goodness_threshold ] 
    users_band_by_months[month] = users_band_by_months[month] + bad_users
    #users_banned = users_banned + bad_users

    # Check number of ratings that will be prevented in subsequent months
    for bad_user in bad_users:
        in_edges_dropped, out_edges_dropped = ban_user(temporal_graph, bad_user, month, verbose=False)

        if in_edges_dropped or out_edges_dropped:
            if len(in_edges_dropped) > 0:
                for k, v in in_edges_dropped.items():
                    if k not in all_in_edges_dropped[month]:
                        all_in_edges_dropped[month][k] = v
                    else:
                        all_in_edges_dropped[month][k] = all_in_edges_dropped[month][k] + v
            if len(out_edges_dropped) > 0:
                for k, v in out_edges_dropped.items():
                    if k not in all_out_edges_dropped[month]:
                        all_out_edges_dropped[month][k] = v
                    else:
                        all_out_edges_dropped[month][k] = all_out_edges_dropped[month][k] + v
        else:
            if month in user_no_future_ratings:
                user_no_future_ratings[month].append(bad_user)
            else:
                user_no_future_ratings[month] = [bad_user]

    print('Effects of banning users in this month:')
    print(f"{len(bad_users)} bad users were banned")

    future_changed = False

    if len(user_no_future_ratings[month]) > 0:
        print(f'{len(user_no_future_ratings[month])} banned users did not have any future transactions')

    if len(all_in_edges_dropped[month]) > 0:
        future_changed = True
        print('The following future in-ratings would have been prevented:')
        for k in sorted(all_in_edges_dropped[month]):
            print(f'{k}: {all_in_edges_dropped[month][k]} edges')

    if len(all_out_edges_dropped[month]) > 0:
        future_changed = True
        print('\nThe following future out-ratings would have been prevented:')
        for k in sorted(all_out_edges_dropped[month]):
            print(f'{k}: {all_out_edges_dropped[month][k]} edges')
            
    if not future_changed:
        print('Simulation of this month would not have affected the future')

    print(sep)
# Out:
# Simulating for the month 2010-11
# Effects of banning users in this month:
# 0 bad users were banned
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2010-12
# Effects of banning users in this month:
# 0 bad users were banned
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-01
# Effects of banning users in this month:
# 0 bad users were banned
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-02
# Effects of banning users in this month:
# 0 bad users were banned
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-03
# Effects of banning users in this month:
# 1 bad users were banned
# 1 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-04
# Effects of banning users in this month:
# 1 bad users were banned
# 1 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-05
# Effects of banning users in this month:
# 9 bad users were banned
# 9 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-06
# Effects of banning users in this month:
# 18 bad users were banned
# 13 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 6 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 3 edges
# 2: 1 edges
# 3: 0 edges
# 4: 1 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 1 edges
#
# The following future out-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 2 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 1 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-07
# Effects of banning users in this month:
# 5 bad users were banned
# 2 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 9 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 1 edges
# -3: 0 edges
# -2: 0 edges
# -1: 2 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-08
# Effects of banning users in this month:
# 3 bad users were banned
# 2 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-09
# Effects of banning users in this month:
# 0 bad users were banned
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-10
# Effects of banning users in this month:
# 1 bad users were banned
# 1 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-11
# Effects of banning users in this month:
# 2 bad users were banned
# 2 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-12
# Effects of banning users in this month:
# 0 bad users were banned
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-01
# Effects of banning users in this month:
# 4 bad users were banned
# 3 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 3 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-02
# Effects of banning users in this month:
# 2 bad users were banned
# 1 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 2 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-03
# Effects of banning users in this month:
# 5 bad users were banned
# 4 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-04
# Effects of banning users in this month:
# 6 bad users were banned
# 4 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 1 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-05
# Effects of banning users in this month:
# 4 bad users were banned
# 3 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 3 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-06
# Effects of banning users in this month:
# 10 bad users were banned
# 8 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 3 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 1 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-07
# Effects of banning users in this month:
# 12 bad users were banned
# 9 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 3 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 2 edges
# 0: 0 edges
# 1: 18 edges
# 2: 4 edges
# 3: 3 edges
# 4: 2 edges
# 5: 2 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 3 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 3 edges
# 0: 0 edges
# 1: 19 edges
# 2: 4 edges
# 3: 3 edges
# 4: 1 edges
# 5: 1 edges
# 6: 0 edges
# 7: 0 edges
# 8: 2 edges
# 9: 0 edges
# 10: 2 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-08
# Effects of banning users in this month:
# 16 bad users were banned
# 5 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 33 edges
# -9: 2 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 6 edges
# -4: 1 edges
# -3: 2 edges
# -2: 2 edges
# -1: 2 edges
# 0: 0 edges
# 1: 3 edges
# 2: 4 edges
# 3: 0 edges
# 4: 0 edges
# 5: 4 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 3 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 2 edges
# 2: 2 edges
# 3: 0 edges
# 4: 2 edges
# 5: 3 edges
# 6: 0 edges
# 7: 1 edges
# 8: 0 edges
# 9: 1 edges
# 10: 1 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-09
# Effects of banning users in this month:
# 82 bad users were banned
# 40 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 97 edges
# -9: 0 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 4 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 4 edges
# 0: 0 edges
# 1: 3 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 8 edges
#
# The following future out-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 2 edges
# 2: 1 edges
# 3: 0 edges
# 4: 3 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-10
# Effects of banning users in this month:
# 32 bad users were banned
# 26 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 7 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 2 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-11
# Effects of banning users in this month:
# 19 bad users were banned
# 13 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 5 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 2 edges
# 2: 2 edges
# 3: 0 edges
# 4: 1 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 1 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 4 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 1 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-12
# Effects of banning users in this month:
# 25 bad users were banned
# 22 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 7 edges
# -9: 1 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 5 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 1 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 1 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-01
# Effects of banning users in this month:
# 27 bad users were banned
# 18 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 5 edges
# -9: 1 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 1 edges
# -1: 2 edges
# 0: 0 edges
# 1: 1 edges
# 2: 0 edges
# 3: 1 edges
# 4: 1 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 1 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 1 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 1 edges
# 4: 1 edges
# 5: 1 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-02
# Effects of banning users in this month:
# 23 bad users were banned
# 19 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 2 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 5 edges
# 9: 0 edges
# 10: 3 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 1 edges
# 6: 0 edges
# 7: 0 edges
# 8: 1 edges
# 9: 0 edges
# 10: 3 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-03
# Effects of banning users in this month:
# 40 bad users were banned
# 24 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 98 edges
# -9: 1 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 2 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 1 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 1 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 331 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 1 edges
# 2: 0 edges
# 3: 0 edges
# 4: 1 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 2 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-04
# Effects of banning users in this month:
# 17 bad users were banned
# 14 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-05
# Effects of banning users in this month:
# 17 bad users were banned
# 15 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 9 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 1 edges
# -4: 1 edges
# -3: 0 edges
# -2: 0 edges
# -1: 4 edges
# 0: 0 edges
# 1: 3 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 1 edges
# 2: 0 edges
# 3: 0 edges
# 4: 2 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-06
# Effects of banning users in this month:
# 22 bad users were banned
# 22 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-07
# Effects of banning users in this month:
# 37 bad users were banned
# 29 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 28 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 2 edges
# 0: 0 edges
# 1: 9 edges
# 2: 2 edges
# 3: 2 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 10 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 1 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 14 edges
# 2: 4 edges
# 3: 1 edges
# 4: 0 edges
# 5: 1 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 5 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-08
# Effects of banning users in this month:
# 77 bad users were banned
# 63 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 13 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 1 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 2 edges
# 0: 0 edges
# 1: 1 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 1 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-09
# Effects of banning users in this month:
# 30 bad users were banned
# 25 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 3 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 4 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 1 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 3 edges
# 2: 0 edges
# 3: 2 edges
# 4: 0 edges
# 5: 1 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-10
# Effects of banning users in this month:
# 29 bad users were banned
# 26 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 1 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 3 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-11
# Effects of banning users in this month:
# 54 bad users were banned
# 49 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 3 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 1 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-12
# Effects of banning users in this month:
# 101 bad users were banned
# 89 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 14 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-01
# Effects of banning users in this month:
# 64 bad users were banned
# 60 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 1 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-02
# Effects of banning users in this month:
# 62 bad users were banned
# 58 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 1 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 2 edges
# 0: 0 edges
# 1: 1 edges
# 2: 0 edges
# 3: 1 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 1 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 1 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-03
# Effects of banning users in this month:
# 36 bad users were banned
# 32 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 4 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 2 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 1 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 1 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-04
# Effects of banning users in this month:
# 31 bad users were banned
# 28 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 2 edges
# -7: 0 edges
# -6: 0 edges
# -5: 3 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-05
# Effects of banning users in this month:
# 25 bad users were banned
# 23 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-06
# Effects of banning users in this month:
# 29 bad users were banned
# 24 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 3 edges
# -9: 1 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 2 edges
# -4: 0 edges
# -3: 4 edges
# -2: 0 edges
# -1: 4 edges
# 0: 0 edges
# 1: 3 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 4 edges
# 2: 2 edges
# 3: 4 edges
# 4: 1 edges
# 5: 0 edges
# 6: 1 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-07
# Effects of banning users in this month:
# 26 bad users were banned
# 24 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 2 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-08
# Effects of banning users in this month:
# 43 bad users were banned
# 38 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 7 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 4 edges
# -4: 0 edges
# -3: 2 edges
# -2: 2 edges
# -1: 1 edges
# 0: 0 edges
# 1: 19 edges
# 2: 3 edges
# 3: 3 edges
# 4: 1 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 3 edges
# -1: 4 edges
# 0: 0 edges
# 1: 28 edges
# 2: 4 edges
# 3: 3 edges
# 4: 1 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-09
# Effects of banning users in this month:
# 27 bad users were banned
# 26 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-10
# Effects of banning users in this month:
# 27 bad users were banned
# 25 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 3 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-11
# Effects of banning users in this month:
# 23 bad users were banned
# 22 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-12
# Effects of banning users in this month:
# 30 bad users were banned
# 29 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-01
# Effects of banning users in this month:
# 28 bad users were banned
# 27 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-02
# Effects of banning users in this month:
# 27 bad users were banned
# 26 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-03
# Effects of banning users in this month:
# 24 bad users were banned
# 22 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-04
# Effects of banning users in this month:
# 27 bad users were banned
# 26 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-05
# Effects of banning users in this month:
# 29 bad users were banned
# 27 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-06
# Effects of banning users in this month:
# 24 bad users were banned
# 23 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-07
# Effects of banning users in this month:
# 25 bad users were banned
# 24 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-08
# Effects of banning users in this month:
# 26 bad users were banned
# 26 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-09
# Effects of banning users in this month:
# 24 bad users were banned
# 24 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-10
# Effects of banning users in this month:
# 24 bad users were banned
# 24 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-11
# Effects of banning users in this month:
# 25 bad users were banned
# 25 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-12
# Effects of banning users in this month:
# 23 bad users were banned
# 23 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2016-01
# Effects of banning users in this month:
# 24 bad users were banned
# 24 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------

# %%
all_in_edges_dropped_rev2 = pd.DataFrame.from_dict(all_in_edges_dropped, orient='index')
all_out_edges_dropped_rev2 = pd.DataFrame.from_dict(all_out_edges_dropped, orient='index')

# %%
all_in_edges_dropped_rev2.to_csv('all_in_edges_dropped_rev2.csv')
all_out_edges_dropped_rev2.to_csv('all_out_edges_dropped_rev2.csv')

# %% [markdown]
# Summarising the effects of banning users based on goodness scores

# %%
all_in_edges_dropped_summary = {}
all_out_edges_dropped_summary = {}

for k in all_in_edges_dropped:
    if k not in all_in_edges_dropped_summary:
        all_in_edges_dropped_summary[k] = {
            'bad': 0,
            'good': 0
        }
    
    for score, count in all_in_edges_dropped[k].items():
        if score < 0:
            all_in_edges_dropped_summary[k]['bad'] = all_in_edges_dropped_summary[k]['bad'] + count
        else:
            all_in_edges_dropped_summary[k]['good'] = all_in_edges_dropped_summary[k]['good'] + count

for k in all_out_edges_dropped:
    if k not in all_out_edges_dropped_summary:
        all_out_edges_dropped_summary[k] = {
            'bad': 0,
            'good': 0
        }
    
    for score, count in all_out_edges_dropped[k].items():
        if score < 0:
            all_out_edges_dropped_summary[k]['bad'] = all_out_edges_dropped_summary[k]['bad'] + count
        else:
            all_out_edges_dropped_summary[k]['good'] = all_out_edges_dropped_summary[k]['good'] + count

# %%
ban_summary_rev2 = pd.DataFrame.from_dict(all_in_edges_dropped_summary, orient='index')

# %% [markdown]
# ## Banning Based on Average Rating

# %%
average_rating_threshold = -1
users_banned = [-1, -2]
first_month = None
users_banned_by_months = {}
all_in_edges_dropped = {}
all_out_edges_dropped = {}
user_no_future_ratings = {}
sep = '---------------------------------------------------------------------------'

for month in temporal_graph.get_all_months():
    month = str(month)
    month_dt = datetime.strptime(month, '%Y-%m')
    next_month_dt = (month_dt + timedelta(days=31)).replace(day=1)
    next_month = next_month_dt.strftime('%Y-%m')

    if month not in all_in_edges_dropped:
        all_in_edges_dropped[month] = {}
        for i in range(-10, 11):
            all_in_edges_dropped[month][i] = 0
    if month not in all_out_edges_dropped:
        all_out_edges_dropped[month] = {} 
        for i in range(-10, 11):
            all_out_edges_dropped[month][i] = 0
    if month not in user_no_future_ratings:
        user_no_future_ratings[month] = []
    if month not in users_band_by_months:
        users_banned_by_months[month] = deepcopy(users_banned)

    if first_month is None:
        first_month = month

    print(f'Simulating for the month {month}')

    # Create a new directed graph for simulation in each iteration
    simulation_graph = deepcopy(temporal_graph)#, first_month, str(m)) 

    # Remove users that were already banned from simulation_graph
    for k in users_banned_by_months:
        if k < month:
            # Only drop the in-edges from the current month
            simulation_graph.df = simulation_graph.df.drop(
                simulation_graph.df[simulation_graph.df.index > k]
                .query(f"target in ({','.join([str(x) for x in users_banned_by_months[k]])})").index
            )
            simulation_graph.df = simulation_graph.df.drop(
                simulation_graph.df[simulation_graph.df.index > k]
                .query(f"source in ({','.join([str(x) for x in users_banned_by_months[k]])})").index
            )
    
    # In this scenario, we don't need to use goodness score, hence
    # not running REV2 algorithm
    G = simulation_graph.get_DiGraph(first_month, month, run_REV2=False)

    # Find out what users to ban in each month
    bad_users = []
    for node in G.nodes():
        # Getting all in-edges of this node to calculate the average ratings
        in_edges = G.in_edges(node, data=True)
        user_rating_count = 0
        user_total_ratings = 0
        user_average_rating = None
        
        for in_edge in in_edges:
            user_total_ratings = user_total_ratings + in_edge[2]['weight']
            user_rating_count = user_rating_count + 1
        
        if user_rating_count > 0:
            user_average_rating = user_total_ratings / user_rating_count
        
        if user_average_rating is not None and user_average_rating < average_rating_threshold:
            bad_users.append(node)

    #bad_users = [ n[0] for n in G.nodes(data=True) if n[1]['goodness'] < goodness_threshold ] 
    users_band_by_months[month] = users_band_by_months[month] + bad_users
    #users_banned = users_banned + bad_users

    # Check number of ratings that will be prevented in subsequent months
    for bad_user in bad_users:
        in_edges_dropped, out_edges_dropped = ban_user(temporal_graph, bad_user, month, verbose=False)

        if in_edges_dropped or out_edges_dropped:
            if len(in_edges_dropped) > 0:
                for k, v in in_edges_dropped.items():
                    if k not in all_in_edges_dropped[month]:
                        all_in_edges_dropped[month][k] = v
                    else:
                        all_in_edges_dropped[month][k] = all_in_edges_dropped[month][k] + v
            if len(out_edges_dropped) > 0:
                for k, v in out_edges_dropped.items():
                    if k not in all_out_edges_dropped[month]:
                        all_out_edges_dropped[month][k] = v
                    else:
                        all_out_edges_dropped[month][k] = all_out_edges_dropped[month][k] + v
        else:
            if month in user_no_future_ratings:
                user_no_future_ratings[month].append(bad_user)
            else:
                user_no_future_ratings[month] = [bad_user]

    print('Effects of banning users in this month:')
    print(f"{len(bad_users)} bad users were banned")

    future_changed = False

    if len(user_no_future_ratings[month]) > 0:
        print(f'{len(user_no_future_ratings[month])} banned users did not have any future transactions')

    if len(all_in_edges_dropped[month]) > 0:
        future_changed = True
        print('The following future in-ratings would have been prevented:')
        for k in sorted(all_in_edges_dropped[month]):
            print(f'{k}: {all_in_edges_dropped[month][k]} edges')

    if len(all_out_edges_dropped[month]) > 0:
        future_changed = True
        print('\nThe following future out-ratings would have been prevented:')
        for k in sorted(all_out_edges_dropped[month]):
            print(f'{k}: {all_out_edges_dropped[month][k]} edges')
            
    if not future_changed:
        print('Simulation of this month would not have affected the future')

    print(sep)
# Out:
# Simulating for the month 2010-11
# Effects of banning users in this month:
# 0 bad users were banned
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2010-12
# Effects of banning users in this month:
# 0 bad users were banned
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-01
# Effects of banning users in this month:
# 0 bad users were banned
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-02
# Effects of banning users in this month:
# 0 bad users were banned
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-03
# Effects of banning users in this month:
# 0 bad users were banned
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-04
# Effects of banning users in this month:
# 1 bad users were banned
# 1 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-05
# Effects of banning users in this month:
# 9 bad users were banned
# 9 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-06
# Effects of banning users in this month:
# 25 bad users were banned
# 20 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 6 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 4 edges
# 2: 3 edges
# 3: 0 edges
# 4: 1 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 2 edges
#
# The following future out-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 4 edges
# 2: 5 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 1 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-07
# Effects of banning users in this month:
# 31 bad users were banned
# 27 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 3 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-08
# Effects of banning users in this month:
# 34 bad users were banned
# 32 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-09
# Effects of banning users in this month:
# 34 bad users were banned
# 33 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-10
# Effects of banning users in this month:
# 35 bad users were banned
# 34 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-11
# Effects of banning users in this month:
# 36 bad users were banned
# 35 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2011-12
# Effects of banning users in this month:
# 36 bad users were banned
# 35 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-01
# Effects of banning users in this month:
# 39 bad users were banned
# 37 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 3 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-02
# Effects of banning users in this month:
# 40 bad users were banned
# 39 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-03
# Effects of banning users in this month:
# 44 bad users were banned
# 42 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 2 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-04
# Effects of banning users in this month:
# 48 bad users were banned
# 44 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 1 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 2 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-05
# Effects of banning users in this month:
# 50 bad users were banned
# 46 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 3 edges
# -9: 1 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 3 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-06
# Effects of banning users in this month:
# 56 bad users were banned
# 52 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 2 edges
# 0: 0 edges
# 1: 1 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-07
# Effects of banning users in this month:
# 63 bad users were banned
# 58 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 4 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 3 edges
# 0: 0 edges
# 1: 2 edges
# 2: 2 edges
# 3: 0 edges
# 4: 0 edges
# 5: 1 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 2 edges
# 9: 0 edges
# 10: 2 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-08
# Effects of banning users in this month:
# 75 bad users were banned
# 61 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 32 edges
# -9: 2 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 4 edges
# -4: 1 edges
# -3: 2 edges
# -2: 2 edges
# -1: 5 edges
# 0: 0 edges
# 1: 5 edges
# 2: 6 edges
# 3: 0 edges
# 4: 0 edges
# 5: 5 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 3 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 2 edges
# 2: 3 edges
# 3: 0 edges
# 4: 2 edges
# 5: 3 edges
# 6: 0 edges
# 7: 1 edges
# 8: 2 edges
# 9: 1 edges
# 10: 3 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-09
# Effects of banning users in this month:
# 131 bad users were banned
# 103 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 92 edges
# -9: 2 edges
# -8: 2 edges
# -7: 0 edges
# -6: 0 edges
# -5: 8 edges
# -4: 1 edges
# -3: 0 edges
# -2: 2 edges
# -1: 8 edges
# 0: 0 edges
# 1: 7 edges
# 2: 4 edges
# 3: 0 edges
# 4: 0 edges
# 5: 4 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 8 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 1 edges
# 3: 0 edges
# 4: 3 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 1 edges
# 9: 0 edges
# 10: 2 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-10
# Effects of banning users in this month:
# 182 bad users were banned
# 168 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 65 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 5 edges
# -4: 1 edges
# -3: 0 edges
# -2: 2 edges
# -1: 9 edges
# 0: 0 edges
# 1: 9 edges
# 2: 4 edges
# 3: 0 edges
# 4: 0 edges
# 5: 3 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 8 edges
#
# The following future out-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 2 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 1 edges
# 9: 0 edges
# 10: 2 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-11
# Effects of banning users in this month:
# 194 bad users were banned
# 178 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 62 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 7 edges
# -4: 0 edges
# -3: 0 edges
# -2: 2 edges
# -1: 7 edges
# 0: 0 edges
# 1: 8 edges
# 2: 3 edges
# 3: 0 edges
# 4: 0 edges
# 5: 3 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 8 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 1 edges
# 9: 0 edges
# 10: 2 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2012-12
# Effects of banning users in this month:
# 208 bad users were banned
# 196 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 53 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 7 edges
# -4: 0 edges
# -3: 0 edges
# -2: 2 edges
# -1: 7 edges
# 0: 0 edges
# 1: 5 edges
# 2: 3 edges
# 3: 0 edges
# 4: 0 edges
# 5: 3 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 8 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 1 edges
# 9: 0 edges
# 10: 2 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-01
# Effects of banning users in this month:
# 228 bad users were banned
# 210 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 58 edges
# -9: 4 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 7 edges
# -4: 0 edges
# -3: 1 edges
# -2: 2 edges
# -1: 8 edges
# 0: 0 edges
# 1: 7 edges
# 2: 5 edges
# 3: 0 edges
# 4: 1 edges
# 5: 4 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 14 edges
#
# The following future out-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 4 edges
# 2: 3 edges
# 3: 1 edges
# 4: 1 edges
# 5: 1 edges
# 6: 0 edges
# 7: 0 edges
# 8: 1 edges
# 9: 0 edges
# 10: 3 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-02
# Effects of banning users in this month:
# 241 bad users were banned
# 223 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 58 edges
# -9: 4 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 5 edges
# -4: 0 edges
# -3: 0 edges
# -2: 2 edges
# -1: 5 edges
# 0: 0 edges
# 1: 4 edges
# 2: 2 edges
# 3: 0 edges
# 4: 0 edges
# 5: 3 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 13 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 1 edges
# 6: 0 edges
# 7: 0 edges
# 8: 2 edges
# 9: 0 edges
# 10: 6 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-03
# Effects of banning users in this month:
# 264 bad users were banned
# 233 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 132 edges
# -9: 5 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 6 edges
# -4: 0 edges
# -3: 0 edges
# -2: 1 edges
# -1: 5 edges
# 0: 0 edges
# 1: 4 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 1 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 1 edges
# 10: 3 edges
#
# The following future out-ratings would have been prevented:
# -10: 331 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 1 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 1 edges
# 9: 0 edges
# 10: 4 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-04
# Effects of banning users in this month:
# 273 bad users were banned
# 240 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 105 edges
# -9: 4 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 6 edges
# -4: 0 edges
# -3: 0 edges
# -2: 1 edges
# -1: 3 edges
# 0: 0 edges
# 1: 3 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 1 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 1 edges
# 10: 3 edges
#
# The following future out-ratings would have been prevented:
# -10: 331 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 1 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 1 edges
# 9: 0 edges
# 10: 4 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-05
# Effects of banning users in this month:
# 279 bad users were banned
# 250 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 92 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 6 edges
# -4: 1 edges
# -3: 0 edges
# -2: 1 edges
# -1: 5 edges
# 0: 0 edges
# 1: 5 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 1 edges
# 10: 3 edges
#
# The following future out-ratings would have been prevented:
# -10: 331 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 2 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 2 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-06
# Effects of banning users in this month:
# 289 bad users were banned
# 260 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 88 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 6 edges
# -4: 1 edges
# -3: 0 edges
# -2: 1 edges
# -1: 5 edges
# 0: 0 edges
# 1: 5 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 1 edges
# 10: 3 edges
#
# The following future out-ratings would have been prevented:
# -10: 331 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 2 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 2 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-07
# Effects of banning users in this month:
# 315 bad users were banned
# 283 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 61 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 6 edges
# -4: 1 edges
# -3: 0 edges
# -2: 1 edges
# -1: 7 edges
# 0: 0 edges
# 1: 13 edges
# 2: 2 edges
# 3: 2 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 1 edges
#
# The following future out-ratings would have been prevented:
# -10: 270 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 15 edges
# 2: 4 edges
# 3: 1 edges
# 4: 0 edges
# 5: 1 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 5 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-08
# Effects of banning users in this month:
# 387 bad users were banned
# 351 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 50 edges
# -9: 2 edges
# -8: 0 edges
# -7: 1 edges
# -6: 0 edges
# -5: 6 edges
# -4: 1 edges
# -3: 1 edges
# -2: 1 edges
# -1: 8 edges
# 0: 0 edges
# 1: 88 edges
# 2: 41 edges
# 3: 21 edges
# 4: 6 edges
# 5: 8 edges
# 6: 2 edges
# 7: 2 edges
# 8: 2 edges
# 9: 0 edges
# 10: 7 edges
#
# The following future out-ratings would have been prevented:
# -10: 4 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 1 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 92 edges
# 2: 39 edges
# 3: 21 edges
# 4: 7 edges
# 5: 6 edges
# 6: 5 edges
# 7: 4 edges
# 8: 0 edges
# 9: 1 edges
# 10: 4 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-09
# Effects of banning users in this month:
# 401 bad users were banned
# 366 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 50 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 6 edges
# -4: 1 edges
# -3: 1 edges
# -2: 1 edges
# -1: 7 edges
# 0: 0 edges
# 1: 62 edges
# 2: 22 edges
# 3: 12 edges
# 4: 3 edges
# 5: 5 edges
# 6: 0 edges
# 7: 1 edges
# 8: 1 edges
# 9: 0 edges
# 10: 5 edges
#
# The following future out-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 62 edges
# 2: 19 edges
# 3: 14 edges
# 4: 4 edges
# 5: 3 edges
# 6: 1 edges
# 7: 1 edges
# 8: 0 edges
# 9: 1 edges
# 10: 3 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-10
# Effects of banning users in this month:
# 406 bad users were banned
# 371 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 48 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 7 edges
# -4: 1 edges
# -3: 1 edges
# -2: 1 edges
# -1: 8 edges
# 0: 0 edges
# 1: 52 edges
# 2: 21 edges
# 3: 11 edges
# 4: 2 edges
# 5: 4 edges
# 6: 0 edges
# 7: 1 edges
# 8: 1 edges
# 9: 0 edges
# 10: 5 edges
#
# The following future out-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 1 edges
# 0: 0 edges
# 1: 51 edges
# 2: 19 edges
# 3: 11 edges
# 4: 4 edges
# 5: 2 edges
# 6: 1 edges
# 7: 1 edges
# 8: 0 edges
# 9: 1 edges
# 10: 3 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-11
# Effects of banning users in this month:
# 431 bad users were banned
# 395 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 47 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 7 edges
# -4: 1 edges
# -3: 1 edges
# -2: 1 edges
# -1: 7 edges
# 0: 0 edges
# 1: 37 edges
# 2: 15 edges
# 3: 7 edges
# 4: 2 edges
# 5: 4 edges
# 6: 0 edges
# 7: 1 edges
# 8: 1 edges
# 9: 0 edges
# 10: 3 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 29 edges
# 2: 14 edges
# 3: 7 edges
# 4: 3 edges
# 5: 2 edges
# 6: 1 edges
# 7: 1 edges
# 8: 0 edges
# 9: 1 edges
# 10: 2 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2013-12
# Effects of banning users in this month:
# 510 bad users were banned
# 466 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 57 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 8 edges
# -4: 1 edges
# -3: 3 edges
# -2: 2 edges
# -1: 9 edges
# 0: 0 edges
# 1: 67 edges
# 2: 31 edges
# 3: 9 edges
# 4: 4 edges
# 5: 9 edges
# 6: 0 edges
# 7: 2 edges
# 8: 1 edges
# 9: 1 edges
# 10: 5 edges
#
# The following future out-ratings would have been prevented:
# -10: 10 edges
# -9: 0 edges
# -8: 0 edges
# -7: 1 edges
# -6: 0 edges
# -5: 5 edges
# -4: 1 edges
# -3: 1 edges
# -2: 2 edges
# -1: 7 edges
# 0: 0 edges
# 1: 64 edges
# 2: 30 edges
# 3: 15 edges
# 4: 6 edges
# 5: 4 edges
# 6: 2 edges
# 7: 1 edges
# 8: 0 edges
# 9: 2 edges
# 10: 4 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-01
# Effects of banning users in this month:
# 549 bad users were banned
# 504 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 57 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 8 edges
# -4: 1 edges
# -3: 3 edges
# -2: 3 edges
# -1: 8 edges
# 0: 0 edges
# 1: 49 edges
# 2: 27 edges
# 3: 7 edges
# 4: 4 edges
# 5: 9 edges
# 6: 0 edges
# 7: 2 edges
# 8: 1 edges
# 9: 1 edges
# 10: 4 edges
#
# The following future out-ratings would have been prevented:
# -10: 10 edges
# -9: 0 edges
# -8: 0 edges
# -7: 1 edges
# -6: 0 edges
# -5: 5 edges
# -4: 1 edges
# -3: 1 edges
# -2: 2 edges
# -1: 7 edges
# 0: 0 edges
# 1: 46 edges
# 2: 26 edges
# 3: 13 edges
# 4: 6 edges
# 5: 4 edges
# 6: 1 edges
# 7: 1 edges
# 8: 0 edges
# 9: 2 edges
# 10: 4 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-02
# Effects of banning users in this month:
# 578 bad users were banned
# 534 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 54 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 9 edges
# -4: 1 edges
# -3: 3 edges
# -2: 2 edges
# -1: 8 edges
# 0: 0 edges
# 1: 45 edges
# 2: 27 edges
# 3: 6 edges
# 4: 4 edges
# 5: 9 edges
# 6: 0 edges
# 7: 2 edges
# 8: 1 edges
# 9: 1 edges
# 10: 4 edges
#
# The following future out-ratings would have been prevented:
# -10: 10 edges
# -9: 0 edges
# -8: 0 edges
# -7: 1 edges
# -6: 0 edges
# -5: 5 edges
# -4: 1 edges
# -3: 1 edges
# -2: 2 edges
# -1: 7 edges
# 0: 0 edges
# 1: 43 edges
# 2: 26 edges
# 3: 13 edges
# 4: 6 edges
# 5: 4 edges
# 6: 1 edges
# 7: 1 edges
# 8: 0 edges
# 9: 2 edges
# 10: 3 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-03
# Effects of banning users in this month:
# 595 bad users were banned
# 552 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 52 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 7 edges
# -4: 0 edges
# -3: 3 edges
# -2: 4 edges
# -1: 9 edges
# 0: 0 edges
# 1: 46 edges
# 2: 27 edges
# 3: 7 edges
# 4: 4 edges
# 5: 9 edges
# 6: 0 edges
# 7: 2 edges
# 8: 1 edges
# 9: 1 edges
# 10: 3 edges
#
# The following future out-ratings would have been prevented:
# -10: 11 edges
# -9: 0 edges
# -8: 0 edges
# -7: 1 edges
# -6: 0 edges
# -5: 5 edges
# -4: 1 edges
# -3: 1 edges
# -2: 2 edges
# -1: 8 edges
# 0: 0 edges
# 1: 46 edges
# 2: 26 edges
# 3: 13 edges
# 4: 4 edges
# 5: 4 edges
# 6: 1 edges
# 7: 1 edges
# 8: 0 edges
# 9: 2 edges
# 10: 2 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-04
# Effects of banning users in this month:
# 606 bad users were banned
# 570 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 35 edges
# -9: 2 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 7 edges
# -4: 0 edges
# -3: 3 edges
# -2: 3 edges
# -1: 8 edges
# 0: 0 edges
# 1: 32 edges
# 2: 15 edges
# 3: 5 edges
# 4: 2 edges
# 5: 6 edges
# 6: 0 edges
# 7: 1 edges
# 8: 0 edges
# 9: 1 edges
# 10: 1 edges
#
# The following future out-ratings would have been prevented:
# -10: 2 edges
# -9: 0 edges
# -8: 0 edges
# -7: 1 edges
# -6: 0 edges
# -5: 3 edges
# -4: 1 edges
# -3: 1 edges
# -2: 2 edges
# -1: 6 edges
# 0: 0 edges
# 1: 30 edges
# 2: 16 edges
# 3: 8 edges
# 4: 3 edges
# 5: 2 edges
# 6: 1 edges
# 7: 0 edges
# 8: 0 edges
# 9: 1 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-05
# Effects of banning users in this month:
# 610 bad users were banned
# 577 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 33 edges
# -9: 2 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 6 edges
# -4: 0 edges
# -3: 3 edges
# -2: 0 edges
# -1: 8 edges
# 0: 0 edges
# 1: 30 edges
# 2: 14 edges
# 3: 5 edges
# 4: 2 edges
# 5: 6 edges
# 6: 0 edges
# 7: 1 edges
# 8: 0 edges
# 9: 1 edges
# 10: 1 edges
#
# The following future out-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 1 edges
# -6: 0 edges
# -5: 3 edges
# -4: 1 edges
# -3: 1 edges
# -2: 2 edges
# -1: 5 edges
# 0: 0 edges
# 1: 30 edges
# 2: 15 edges
# 3: 8 edges
# 4: 3 edges
# 5: 2 edges
# 6: 1 edges
# 7: 0 edges
# 8: 0 edges
# 9: 1 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-06
# Effects of banning users in this month:
# 618 bad users were banned
# 583 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 34 edges
# -9: 3 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 5 edges
# -4: 0 edges
# -3: 5 edges
# -2: 0 edges
# -1: 10 edges
# 0: 0 edges
# 1: 31 edges
# 2: 14 edges
# 3: 4 edges
# 4: 2 edges
# 5: 6 edges
# 6: 0 edges
# 7: 1 edges
# 8: 0 edges
# 9: 1 edges
# 10: 1 edges
#
# The following future out-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 1 edges
# -6: 0 edges
# -5: 1 edges
# -4: 1 edges
# -3: 1 edges
# -2: 2 edges
# -1: 3 edges
# 0: 0 edges
# 1: 32 edges
# 2: 17 edges
# 3: 10 edges
# 4: 4 edges
# 5: 2 edges
# 6: 2 edges
# 7: 0 edges
# 8: 0 edges
# 9: 1 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-07
# Effects of banning users in this month:
# 621 bad users were banned
# 587 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 29 edges
# -9: 3 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 4 edges
# -4: 0 edges
# -3: 5 edges
# -2: 0 edges
# -1: 9 edges
# 0: 0 edges
# 1: 31 edges
# 2: 14 edges
# 3: 2 edges
# 4: 2 edges
# 5: 6 edges
# 6: 0 edges
# 7: 1 edges
# 8: 0 edges
# 9: 1 edges
# 10: 1 edges
#
# The following future out-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 1 edges
# -6: 0 edges
# -5: 1 edges
# -4: 1 edges
# -3: 1 edges
# -2: 1 edges
# -1: 2 edges
# 0: 0 edges
# 1: 31 edges
# 2: 15 edges
# 3: 5 edges
# 4: 3 edges
# 5: 2 edges
# 6: 1 edges
# 7: 0 edges
# 8: 0 edges
# 9: 1 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-08
# Effects of banning users in this month:
# 639 bad users were banned
# 610 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 25 edges
# -9: 3 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 1 edges
# -4: 0 edges
# -3: 6 edges
# -2: 0 edges
# -1: 5 edges
# 0: 0 edges
# 1: 39 edges
# 2: 14 edges
# 3: 5 edges
# 4: 2 edges
# 5: 5 edges
# 6: 0 edges
# 7: 1 edges
# 8: 0 edges
# 9: 1 edges
# 10: 1 edges
#
# The following future out-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 1 edges
# -6: 0 edges
# -5: 1 edges
# -4: 1 edges
# -3: 0 edges
# -2: 1 edges
# -1: 4 edges
# 0: 0 edges
# 1: 37 edges
# 2: 16 edges
# 3: 6 edges
# 4: 3 edges
# 5: 2 edges
# 6: 1 edges
# 7: 0 edges
# 8: 0 edges
# 9: 1 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-09
# Effects of banning users in this month:
# 643 bad users were banned
# 615 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 22 edges
# -9: 2 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 1 edges
# -4: 0 edges
# -3: 5 edges
# -2: 0 edges
# -1: 4 edges
# 0: 0 edges
# 1: 39 edges
# 2: 13 edges
# 3: 5 edges
# 4: 2 edges
# 5: 5 edges
# 6: 0 edges
# 7: 1 edges
# 8: 0 edges
# 9: 1 edges
# 10: 1 edges
#
# The following future out-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 1 edges
# -6: 0 edges
# -5: 1 edges
# -4: 1 edges
# -3: 0 edges
# -2: 1 edges
# -1: 4 edges
# 0: 0 edges
# 1: 37 edges
# 2: 14 edges
# 3: 6 edges
# 4: 3 edges
# 5: 2 edges
# 6: 1 edges
# 7: 0 edges
# 8: 0 edges
# 9: 1 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-10
# Effects of banning users in this month:
# 645 bad users were banned
# 618 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 24 edges
# -9: 2 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 1 edges
# -4: 0 edges
# -3: 4 edges
# -2: 0 edges
# -1: 4 edges
# 0: 0 edges
# 1: 26 edges
# 2: 13 edges
# 3: 2 edges
# 4: 2 edges
# 5: 4 edges
# 6: 0 edges
# 7: 1 edges
# 8: 0 edges
# 9: 1 edges
# 10: 1 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 1 edges
# -6: 0 edges
# -5: 1 edges
# -4: 1 edges
# -3: 0 edges
# -2: 1 edges
# -1: 2 edges
# 0: 0 edges
# 1: 24 edges
# 2: 12 edges
# 3: 5 edges
# 4: 2 edges
# 5: 2 edges
# 6: 1 edges
# 7: 0 edges
# 8: 0 edges
# 9: 1 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-11
# Effects of banning users in this month:
# 644 bad users were banned
# 620 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 23 edges
# -9: 2 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 4 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2014-12
# Effects of banning users in this month:
# 651 bad users were banned
# 644 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 6 edges
# -9: 2 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 4 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-01
# Effects of banning users in this month:
# 653 bad users were banned
# 650 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 2 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-02
# Effects of banning users in this month:
# 658 bad users were banned
# 654 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 2 edges
# -9: 2 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-03
# Effects of banning users in this month:
# 659 bad users were banned
# 655 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 2 edges
# -9: 2 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-04
# Effects of banning users in this month:
# 662 bad users were banned
# 658 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 2 edges
# -9: 2 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-05
# Effects of banning users in this month:
# 664 bad users were banned
# 661 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 2 edges
# -9: 1 edges
# -8: 1 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 1 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 2 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 3 edges
# 2: 1 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-06
# Effects of banning users in this month:
# 664 bad users were banned
# 663 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-07
# Effects of banning users in this month:
# 665 bad users were banned
# 664 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 1 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-08
# Effects of banning users in this month:
# 668 bad users were banned
# 668 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-09
# Effects of banning users in this month:
# 668 bad users were banned
# 668 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-10
# Effects of banning users in this month:
# 668 bad users were banned
# 668 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-11
# Effects of banning users in this month:
# 669 bad users were banned
# 669 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2015-12
# Effects of banning users in this month:
# 669 bad users were banned
# 669 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------
# Simulating for the month 2016-01
# Effects of banning users in this month:
# 669 bad users were banned
# 669 banned users did not have any future transactions
# The following future in-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
#
# The following future out-ratings would have been prevented:
# -10: 0 edges
# -9: 0 edges
# -8: 0 edges
# -7: 0 edges
# -6: 0 edges
# -5: 0 edges
# -4: 0 edges
# -3: 0 edges
# -2: 0 edges
# -1: 0 edges
# 0: 0 edges
# 1: 0 edges
# 2: 0 edges
# 3: 0 edges
# 4: 0 edges
# 5: 0 edges
# 6: 0 edges
# 7: 0 edges
# 8: 0 edges
# 9: 0 edges
# 10: 0 edges
# ---------------------------------------------------------------------------

# %%
all_in_edges_dropped_average_ratings = pd.DataFrame.from_dict(all_in_edges_dropped, orient='index')
all_out_edges_dropped_average_ratings = pd.DataFrame.from_dict(all_out_edges_dropped, orient='index')

# %%
all_in_edges_dropped_average_ratings.to_csv('all_in_edges_dropped_average_ratings.csv')
all_out_edges_dropped_average_ratings.to_csv('all_out_edges_dropped_average_ratings.csv')

# %%
all_in_edges_dropped_summary = {}
all_out_edges_dropped_summary = {}

for k in all_in_edges_dropped:
    if k not in all_in_edges_dropped_summary:
        all_in_edges_dropped_summary[k] = {
            'bad': 0,
            'good': 0
        }
    
    for score, count in all_in_edges_dropped[k].items():
        if score < 0:
            all_in_edges_dropped_summary[k]['bad'] = all_in_edges_dropped_summary[k]['bad'] + count
        else:
            all_in_edges_dropped_summary[k]['good'] = all_in_edges_dropped_summary[k]['good'] + count

for k in all_out_edges_dropped:
    if k not in all_out_edges_dropped_summary:
        all_out_edges_dropped_summary[k] = {
            'bad': 0,
            'good': 0
        }
    
    for score, count in all_out_edges_dropped[k].items():
        if score < 0:
            all_out_edges_dropped_summary[k]['bad'] = all_out_edges_dropped_summary[k]['bad'] + count
        else:
            all_out_edges_dropped_summary[k]['good'] = all_out_edges_dropped_summary[k]['good'] + count

# %%
ban_summary_avgrating = pd.DataFrame.from_dict(all_in_edges_dropped_summary, orient='index')

# %%
total_ratings_stopped = sum(ban_summary_rev2.sum())
bad_ratings_stopped = ban_summary_rev2.sum()['bad']
good_ratings_stopped = ban_summary_rev2.sum()['good']
print(f"""
Using REV2 goodness score to ban users, it would have prevented {bad_ratings_stopped} bad ratings ({round(bad_ratings_stopped / total_ratings_stopped, 2)*100}%) and {good_ratings_stopped} good ratings ({round(good_ratings_stopped / total_ratings_stopped, 2)*100}%).
""")
# Out:
# Using REV2 goodness score to ban users, it would have prevented 501 bad ratings (77.0%) and 148 good ratings (23.0%).

# %%
total_ratings_stopped = sum(ban_summary_avgrating.sum())
bad_ratings_stopped = ban_summary_avgrating.sum()['bad']
good_ratings_stopped = ban_summary_avgrating.sum()['good']
print(f"""
Using average ratings to ban users, it would have prevented {bad_ratings_stopped} bad ratings ({round(bad_ratings_stopped / total_ratings_stopped, 2)*100}%) and {good_ratings_stopped} good ratings ({round(good_ratings_stopped / total_ratings_stopped, 2)*100}%).
""")
# Out:
# Using average ratings to ban users, it would have prevented 2147 bad ratings (57.99999999999999%) and 1568 good ratings (42.0%).

# %%
ban_summary_rev2
# Out:
#          bad  good
# 2010-11    0     0
# 2010-12    0     0
# 2011-01    0     0
# 2011-02    0     0
# 2011-03    0     0
# ...      ...   ...
# 2015-09    0     0
# 2015-10    0     0
# 2015-11    0     0
# 2015-12    0     0
# 2016-01    0     0
#
# [63 rows x 2 columns]
